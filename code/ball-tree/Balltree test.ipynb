# %%
#Stupid hack to load files from sibling dir
import sys; import os
sys.path.insert(0, os.path.abspath('..'))

# %load_ext autoreload
# %autoreload 2

# %%
from sklearn.neighbors.ball_tree import BallTree
import copy
import features
import display
# Out:
# /usr/lib/python2.7/dist-packages/nose/util.py:14: DeprecationWarning: The compiler package is deprecated and removed in Python 3.x.
#   from compiler.consts import CO_GENERATOR

# %%
#paths = ['../../images/gallagher/partial_match/100_1941.jpg', '../../images/gallagher/partial_match/100_1942.jpg']
#paths = ['../../images/gallagher/partial_match/100_1951.jpg', '../../images/gallagher/partial_match/100_1952.jpg']
#paths = ['../../images/gallagher/partial_match/100_1998.jpg', '../../images/gallagher/partial_match/100_1999.jpg']
#paths = ['../../images/gallagher/partial_match/slide_2.jpg', '../../images/gallagher/partial_match/slide_1.jpg']
#paths = ['../../images/gallagher/partial_match/boat_2.pgm', '../../images/gallagher/partial_match/boat_1.pgm']
#paths = ['../../images/gallagher/partial_match/boat_3.pgm', '../../images/gallagher/partial_match/boat_1.pgm']
#paths = ['../../images/gallagher/partial_match/boat_4.pgm', '../../images/gallagher/partial_match/boat_1.pgm']
#paths = ['../../images/gallagher/partial_match/skyline_2.jpg', '../../images/gallagher/partial_match/skyline_1.jpg']
#paths = ['../../images/gallagher/partial_match/stairs_2.jpg', '../../images/gallagher/partial_match/stairs_1.jpg']
#paths = ['../../images/gallagher/partial_match/slide2_2.jpg', '../../images/gallagher/partial_match/slide2_1.jpg']
paths = ['../../images/gallagher/partial_match/100_2151_small.jpg', '../../images/gallagher/partial_match/100_2154_small.jpg']
#paths = ['../../images/gallagher/partial_match/100_1941_small.jpg', '../../images/gallagher/partial_match/100_1942_small.jpg']
#paths = ['../../images/gallagher/partial_match/100_1951_small.jpg', '../../images/gallagher/partial_match/100_1952_small.jpg']
#paths = ['../../images/gallagher/partial_match/100_1998_small.jpg', '../../images/gallagher/partial_match/100_1999_small.jpg']
#paths = ['../../images/gallagher/partial_match/100_2151_vert.jpg', '../../images/gallagher/partial_match/100_2155_vert.jpg']
#paths = ['../../images/gallagher/partial_match/skyline3_2.jpg', '../../images/gallagher/partial_match/skyline2_1.jpg']
#paths = ['../../images/florian/3a.jpg', '../../images/florian/3b.jpg']
#paths = ['../../images/florian/6a.jpg', '../../images/florian/6b.jpg']
#paths = ['../../images/florian/freddy_2.jpg', '../../images/florian/freddy_1.jpg']
#paths = ['../../images/gallagher/partial_match/water_2.jpg', '../../images/gallagher/partial_match/water_1.jpg']
#paths = ['../../images/florian/lion_1.jpg', '../../images/florian/freddy_1.jpg']
#paths = ['../../images/testsets/NEWYORK/1YQ1YK_1.jpg', '../../images/testsets/NEWYORK/1YQ1YK_2.jpg']

# %%
dt = 5
keypoint_type = "SIFT"
descriptor_type = "SIFT"

# %%
# Get images
images = map(features.loadImage, paths)

# Get keypoints
indices, ks, ds = features.getFeatures(paths, keypoint_type, descriptor_type)
pos = features.getPositions(ks)
positions = numpy.array(pos)
ds.shape
# Out:
# (4956, 128)

# %%
bt = BallTree(ds, leaf_size=2)

# %%
(ind, dis) = bt.query_radius(ds[0], 364, return_distance = True, )
dis[0]
# Out:
# array([ 344.05377487,  325.26297053,  356.55714829,  352.64146098,
#         358.08797802,   51.4781507 ,    0.        ,  314.11940405,
#         358.50523009,  324.21289302,  346.12425515,  356.5487344 ,
#         356.52208908,  344.93477644,  327.28122464,  335.91665633,
#         349.50965652,  362.72165637,  343.06121903,  335.42808469,
#         327.97713335,  326.24683907,  360.00555551,  303.66428832,
#         314.02866111,  322.88078295,  334.47122447,  347.8332934 ,
#         342.03947141,  309.52221245,  340.17054546,  329.66043135,
#         328.39305717,  319.01253894,  336.3941141 ,  341.50109809,
#         350.61659972,  360.33872953,  355.60511807,  341.40005858,
#         328.8966403 ,  333.69896614,  361.16893554,  354.35716445,
#         338.79935065,  363.31666628,  326.43988727,  301.59575594,
#         335.70224902,  333.21764659,  286.85536425,  342.69519985,
#         295.64336624,  327.29191863,  361.22430704,  350.32413562])

# %%
for i,d in enumerate(bt.node_data) :
    if d['radius'] < 300 :
        print("%000i: %s" % (i, str(d)))
# Out:
# 216: {'idx_end': 3484, 'is_leaf': 0, 'radius': 266.7081131499131, 'idx_start': 3445}
# 362: {'idx_end': 2090, 'is_leaf': 0, 'radius': 282.6804512165636, 'idx_start': 2070}
# 372: {'idx_end': 2284, 'is_leaf': 0, 'radius': 250.96512207874622, 'idx_start': 2264}
# 376: {'idx_end': 2361, 'is_leaf': 0, 'radius': 284.0482772746821, 'idx_start': 2342}
# 380: {'idx_end': 2439, 'is_leaf': 0, 'radius': 295.36654769963377, 'idx_start': 2419}
# 381: {'idx_end': 2458, 'is_leaf': 0, 'radius': 289.4794162111916, 'idx_start': 2439}
# 382: {'idx_end': 2478, 'is_leaf': 0, 'radius': 275.2325652970593, 'idx_start': 2458}
# 421: {'idx_end': 3232, 'is_leaf': 0, 'radius': 217.37953966720966, 'idx_start': 3213}
# 433: {'idx_end': 3464, 'is_leaf': 0, 'radius': 250.84928871928165, 'idx_start': 3445}
# 434: {'idx_end': 3484, 'is_leaf': 0, 'radius': 259.8404943422023, 'idx_start': 3464}
# 446: {'idx_end': 3717, 'is_leaf': 0, 'radius': 292.18577566336114, 'idx_start': 3697}
# 451: {'idx_end': 3813, 'is_leaf': 0, 'radius': 284.7785648972387, 'idx_start': 3794}
# 469: {'idx_end': 4161, 'is_leaf': 0, 'radius': 295.094590215604, 'idx_start': 4142}
# 470: {'idx_end': 4181, 'is_leaf': 0, 'radius': 260.66412775830895, 'idx_start': 4161}
# 532: {'idx_end': 211, 'is_leaf': 0, 'radius': 234.30484416673934, 'idx_start': 201}
# 539: {'idx_end': 279, 'is_leaf': 0, 'radius': 201.29313432386593, 'idx_start': 270}
# 547: {'idx_end': 356, 'is_leaf': 0, 'radius': 200.09139886870344, 'idx_start': 347}
# 553: {'idx_end': 415, 'is_leaf': 0, 'radius': 299.95963061718817, 'idx_start': 405}
# 554: {'idx_end': 425, 'is_leaf': 0, 'radius': 198.1001009590859, 'idx_start': 415}
# 598: {'idx_end': 851, 'is_leaf': 0, 'radius': 299.64954530250833, 'idx_start': 841}
# 602: {'idx_end': 890, 'is_leaf': 0, 'radius': 295.7783629679493, 'idx_start': 880}
# 605: {'idx_end': 919, 'is_leaf': 0, 'radius': 275.678308903693, 'idx_start': 909}
# 662: {'idx_end': 1470, 'is_leaf': 0, 'radius': 292.7400040992006, 'idx_start': 1460}
# 664: {'idx_end': 1489, 'is_leaf': 0, 'radius': 280.82610277536526, 'idx_start': 1479}
# 697: {'idx_end': 1809, 'is_leaf': 0, 'radius': 169.7375621363757, 'idx_start': 1799}
# 706: {'idx_end': 1896, 'is_leaf': 0, 'radius': 261.066983741721, 'idx_start': 1886}
# 723: {'idx_end': 2060, 'is_leaf': 0, 'radius': 296.09641406094914, 'idx_start': 2051}
# 725: {'idx_end': 2080, 'is_leaf': 0, 'radius': 271.8791643359233, 'idx_start': 2070}
# 726: {'idx_end': 2090, 'is_leaf': 0, 'radius': 269.2408401413128, 'idx_start': 2080}
# 736: {'idx_end': 2187, 'is_leaf': 0, 'radius': 292.15487331208425, 'idx_start': 2177}
# 737: {'idx_end': 2196, 'is_leaf': 0, 'radius': 293.67808024232045, 'idx_start': 2187}
# 744: {'idx_end': 2264, 'is_leaf': 0, 'radius': 291.17422619455857, 'idx_start': 2254}
# 745: {'idx_end': 2274, 'is_leaf': 0, 'radius': 225.95012724050412, 'idx_start': 2264}
# 746: {'idx_end': 2284, 'is_leaf': 0, 'radius': 223.3106132721864, 'idx_start': 2274}
# 747: {'idx_end': 2293, 'is_leaf': 0, 'radius': 283.4921341474165, 'idx_start': 2284}
# 750: {'idx_end': 2323, 'is_leaf': 0, 'radius': 294.9155811414513, 'idx_start': 2313}
# 751: {'idx_end': 2332, 'is_leaf': 0, 'radius': 279.0416359038579, 'idx_start': 2323}
# 752: {'idx_end': 2342, 'is_leaf': 0, 'radius': 264.7452549149843, 'idx_start': 2332}
# 754: {'idx_end': 2361, 'is_leaf': 0, 'radius': 250.7069005831311, 'idx_start': 2351}
# 757: {'idx_end': 2390, 'is_leaf': 0, 'radius': 272.64955529030306, 'idx_start': 2380}
# 759: {'idx_end': 2409, 'is_leaf': 0, 'radius': 290.5599957170827, 'idx_start': 2400}
# 760: {'idx_end': 2419, 'is_leaf': 0, 'radius': 255.55216688574566, 'idx_start': 2409}
# 761: {'idx_end': 2429, 'is_leaf': 0, 'radius': 293.81957048501727, 'idx_start': 2419}
# 762: {'idx_end': 2439, 'is_leaf': 0, 'radius': 252.10741758226789, 'idx_start': 2429}
# 764: {'idx_end': 2458, 'is_leaf': 0, 'radius': 249.75738227327733, 'idx_start': 2448}
# 765: {'idx_end': 2468, 'is_leaf': 0, 'radius': 271.2417003338535, 'idx_start': 2458}
# 766: {'idx_end': 2478, 'is_leaf': 0, 'radius': 260.4426616359155, 'idx_start': 2468}
# 793: {'idx_end': 2738, 'is_leaf': 0, 'radius': 294.98108413930544, 'idx_start': 2728}
# 798: {'idx_end': 2787, 'is_leaf': 0, 'radius': 299.2562948377194, 'idx_start': 2777}
# 825: {'idx_end': 3048, 'is_leaf': 0, 'radius': 296.52746921659724, 'idx_start': 3038}
# 843: {'idx_end': 3222, 'is_leaf': 0, 'radius': 196.6116683926672, 'idx_start': 3213}
# 844: {'idx_end': 3232, 'is_leaf': 0, 'radius': 157.74311395430226, 'idx_start': 3222}
# 851: {'idx_end': 3299, 'is_leaf': 0, 'radius': 254.49053439915096, 'idx_start': 3290}
# 866: {'idx_end': 3445, 'is_leaf': 0, 'radius': 284.18851137933075, 'idx_start': 3435}
# 867: {'idx_end': 3454, 'is_leaf': 0, 'radius': 273.5086610225003, 'idx_start': 3445}
# 868: {'idx_end': 3464, 'is_leaf': 0, 'radius': 232.05971214323264, 'idx_start': 3454}
# 869: {'idx_end': 3474, 'is_leaf': 0, 'radius': 245.40309696497312, 'idx_start': 3464}
# 870: {'idx_end': 3484, 'is_leaf': 0, 'radius': 234.61574968445746, 'idx_start': 3474}
# 871: {'idx_end': 3493, 'is_leaf': 0, 'radius': 294.0580063713809, 'idx_start': 3484}
# 872: {'idx_end': 3503, 'is_leaf': 0, 'radius': 268.3028326350655, 'idx_start': 3493}
# 874: {'idx_end': 3523, 'is_leaf': 0, 'radius': 258.8816524978161, 'idx_start': 3513}
# 879: {'idx_end': 3571, 'is_leaf': 0, 'radius': 271.9211714022836, 'idx_start': 3562}
# 886: {'idx_end': 3639, 'is_leaf': 0, 'radius': 222.7657289620646, 'idx_start': 3629}
# 893: {'idx_end': 3707, 'is_leaf': 0, 'radius': 255.60893959327794, 'idx_start': 3697}
# 894: {'idx_end': 3717, 'is_leaf': 0, 'radius': 280.6878693495678, 'idx_start': 3707}
# 896: {'idx_end': 3736, 'is_leaf': 0, 'radius': 212.58250163171945, 'idx_start': 3726}
# 898: {'idx_end': 3755, 'is_leaf': 0, 'radius': 222.04346421365346, 'idx_start': 3745}
# 901: {'idx_end': 3784, 'is_leaf': 0, 'radius': 276.23240215441785, 'idx_start': 3774}
# 903: {'idx_end': 3803, 'is_leaf': 0, 'radius': 294.3320330494327, 'idx_start': 3794}
# 907: {'idx_end': 3841, 'is_leaf': 0, 'radius': 263.8252320882514, 'idx_start': 3832}
# 913: {'idx_end': 3899, 'is_leaf': 0, 'radius': 171.32425397473642, 'idx_start': 3890}
# 916: {'idx_end': 3928, 'is_leaf': 0, 'radius': 282.8613971541539, 'idx_start': 3918}
# 917: {'idx_end': 3938, 'is_leaf': 0, 'radius': 267.3573264378592, 'idx_start': 3928}
# 918: {'idx_end': 3948, 'is_leaf': 0, 'radius': 292.9722853786686, 'idx_start': 3938}
# 919: {'idx_end': 3957, 'is_leaf': 0, 'radius': 288.239183943637, 'idx_start': 3948}
# 939: {'idx_end': 4151, 'is_leaf': 0, 'radius': 262.9109833863644, 'idx_start': 4142}
# 940: {'idx_end': 4161, 'is_leaf': 0, 'radius': 235.18248234084103, 'idx_start': 4151}
# 941: {'idx_end': 4171, 'is_leaf': 0, 'radius': 203.1561960659827, 'idx_start': 4161}
# 942: {'idx_end': 4181, 'is_leaf': 0, 'radius': 262.1408209340926, 'idx_start': 4171}
# 949: {'idx_end': 4248, 'is_leaf': 0, 'radius': 288.85608873624255, 'idx_start': 4238}
# 958: {'idx_end': 4336, 'is_leaf': 0, 'radius': 281.0192520095376, 'idx_start': 4326}
# 961: {'idx_end': 4364, 'is_leaf': 0, 'radius': 248.38416084369123, 'idx_start': 4355}
# 963: {'idx_end': 4383, 'is_leaf': 0, 'radius': 270.90244702192916, 'idx_start': 4374}
# 966: {'idx_end': 4413, 'is_leaf': 0, 'radius': 278.6940437110202, 'idx_start': 4403}
# 988: {'idx_end': 4626, 'is_leaf': 0, 'radius': 280.64946107199285, 'idx_start': 4616}
# 993: {'idx_end': 4674, 'is_leaf': 0, 'radius': 299.46244019312303, 'idx_start': 4665}
# 998: {'idx_end': 4723, 'is_leaf': 0, 'radius': 295.7611874468995, 'idx_start': 4713}
# 999: {'idx_end': 4732, 'is_leaf': 0, 'radius': 288.59328893748216, 'idx_start': 4723}
# 1004: {'idx_end': 4781, 'is_leaf': 0, 'radius': 252.71766855524768, 'idx_start': 4771}
# 1005: {'idx_end': 4791, 'is_leaf': 0, 'radius': 287.7616895974862, 'idx_start': 4781}
# 1006: {'idx_end': 4801, 'is_leaf': 0, 'radius': 290.9804288951406, 'idx_start': 4791}
# 1007: {'idx_end': 4810, 'is_leaf': 0, 'radius': 283.29391882715106, 'idx_start': 4801}
# 1011: {'idx_end': 4848, 'is_leaf': 0, 'radius': 275.61003045769013, 'idx_start': 4839}
# 1012: {'idx_end': 4858, 'is_leaf': 0, 'radius': 261.28224202957233, 'idx_start': 4848}
# 1013: {'idx_end': 4868, 'is_leaf': 0, 'radius': 241.6532019237486, 'idx_start': 4858}
# 1014: {'idx_end': 4878, 'is_leaf': 0, 'radius': 296.4640787684066, 'idx_start': 4868}
# 1015: {'idx_end': 4887, 'is_leaf': 0, 'radius': 299.5213465465142, 'idx_start': 4878}
# 1016: {'idx_end': 4897, 'is_leaf': 0, 'radius': 179.62229817035524, 'idx_start': 4887}
# 1017: {'idx_end': 4907, 'is_leaf': 0, 'radius': 205.32518111522506, 'idx_start': 4897}
# 1022: {'idx_end': 4956, 'is_leaf': 0, 'radius': 273.0671712234922, 'idx_start': 4946}
# 1046: {'idx_end': 115, 'is_leaf': 0, 'radius': 284.4978031549628, 'idx_start': 110}
# 1054: {'idx_end': 154, 'is_leaf': 0, 'radius': 298.9505644751319, 'idx_start': 149}
# 1059: {'idx_end': 177, 'is_leaf': 0, 'radius': 280.92470076516946, 'idx_start': 173}
# 1061: {'idx_end': 187, 'is_leaf': 0, 'radius': 280.41897225401846, 'idx_start': 182}
# 1062: {'idx_end': 192, 'is_leaf': 0, 'radius': 150.44188246628661, 'idx_start': 187}
# 1065: {'idx_end': 206, 'is_leaf': 0, 'radius': 205.96261796743607, 'idx_start': 201}
# 1066: {'idx_end': 211, 'is_leaf': 0, 'radius': 136.25505495210078, 'idx_start': 206}
# 1070: {'idx_end': 231, 'is_leaf': 0, 'radius': 276.4667068563591, 'idx_start': 226}
# 1076: {'idx_end': 260, 'is_leaf': 0, 'radius': 270.4640456696602, 'idx_start': 255}
# 1078: {'idx_end': 270, 'is_leaf': 0, 'radius': 167.45900990988807, 'idx_start': 265}
# 1079: {'idx_end': 274, 'is_leaf': 0, 'radius': 159.39808656317052, 'idx_start': 270}
# 1080: {'idx_end': 279, 'is_leaf': 0, 'radius': 189.47580320452528, 'idx_start': 274}
# 1081: {'idx_end': 284, 'is_leaf': 0, 'radius': 293.5504045304656, 'idx_start': 279}
# 1082: {'idx_end': 289, 'is_leaf': 0, 'radius': 242.89709755367602, 'idx_start': 284}
# 1083: {'idx_end': 294, 'is_leaf': 0, 'radius': 294.8571179401984, 'idx_start': 289}
# 1085: {'idx_end': 304, 'is_leaf': 0, 'radius': 205.53549571789299, 'idx_start': 299}
# 1094: {'idx_end': 347, 'is_leaf': 0, 'radius': 167.82860304489228, 'idx_start': 342}
# 1095: {'idx_end': 351, 'is_leaf': 0, 'radius': 175.60039863280494, 'idx_start': 347}
# 1096: {'idx_end': 356, 'is_leaf': 0, 'radius': 151.68256326948062, 'idx_start': 351}
# 1106: {'idx_end': 405, 'is_leaf': 0, 'radius': 242.00057851170519, 'idx_start': 400}
# 1107: {'idx_end': 410, 'is_leaf': 0, 'radius': 259.2340255444875, 'idx_start': 405}
# 1108: {'idx_end': 415, 'is_leaf': 0, 'radius': 246.25336545923597, 'idx_start': 410}
# 1109: {'idx_end': 420, 'is_leaf': 0, 'radius': 174.6260003550445, 'idx_start': 415}
# 1110: {'idx_end': 425, 'is_leaf': 0, 'radius': 147.69157051098074, 'idx_start': 420}
# 1111: {'idx_end': 429, 'is_leaf': 0, 'radius': 294.6631551449892, 'idx_start': 425}
# 1112: {'idx_end': 434, 'is_leaf': 0, 'radius': 175.72967876827184, 'idx_start': 429}
# 1117: {'idx_end': 459, 'is_leaf': 0, 'radius': 207.72876546111763, 'idx_start': 454}
# 1120: {'idx_end': 473, 'is_leaf': 0, 'radius': 298.1364788146529, 'idx_start': 468}
# 1122: {'idx_end': 483, 'is_leaf': 0, 'radius': 293.24788149277407, 'idx_start': 478}
# 1131: {'idx_end': 526, 'is_leaf': 0, 'radius': 264.07461066903045, 'idx_start': 521}
# 1132: {'idx_end': 531, 'is_leaf': 0, 'radius': 278.3094680387284, 'idx_start': 526}
# 1134: {'idx_end': 541, 'is_leaf': 0, 'radius': 285.75730961779436, 'idx_start': 536}
# 1138: {'idx_end': 560, 'is_leaf': 0, 'radius': 291.9932190993483, 'idx_start': 555}
# 1143: {'idx_end': 584, 'is_leaf': 0, 'radius': 285.64138355637476, 'idx_start': 580}
# 1145: {'idx_end': 594, 'is_leaf': 0, 'radius': 274.480891866811, 'idx_start': 589}
# 1146: {'idx_end': 599, 'is_leaf': 0, 'radius': 286.0915238171169, 'idx_start': 594}
# 1147: {'idx_end': 604, 'is_leaf': 0, 'radius': 295.3100066032304, 'idx_start': 599}
# 1149: {'idx_end': 614, 'is_leaf': 0, 'radius': 296.8586869202247, 'idx_start': 609}
# 1157: {'idx_end': 652, 'is_leaf': 0, 'radius': 276.09643242896135, 'idx_start': 647}
# 1158: {'idx_end': 657, 'is_leaf': 0, 'radius': 299.2362277532585, 'idx_start': 652}
# 1159: {'idx_end': 661, 'is_leaf': 0, 'radius': 284.07734422160456, 'idx_start': 657}
# 1163: {'idx_end': 681, 'is_leaf': 0, 'radius': 238.30937874955742, 'idx_start': 676}
# 1173: {'idx_end': 730, 'is_leaf': 0, 'radius': 254.17340537514931, 'idx_start': 725}
# 1176: {'idx_end': 744, 'is_leaf': 0, 'radius': 298.19651238738527, 'idx_start': 739}
# 1177: {'idx_end': 749, 'is_leaf': 0, 'radius': 202.82840037825082, 'idx_start': 744}
# 1180: {'idx_end': 764, 'is_leaf': 0, 'radius': 285.4595593074437, 'idx_start': 759}
# 1181: {'idx_end': 769, 'is_leaf': 0, 'radius': 290.8084592992439, 'idx_start': 764}
# 1190: {'idx_end': 812, 'is_leaf': 0, 'radius': 269.5869433040109, 'idx_start': 807}
# 1193: {'idx_end': 826, 'is_leaf': 0, 'radius': 278.9331102612237, 'idx_start': 821}
# 1197: {'idx_end': 846, 'is_leaf': 0, 'radius': 213.51018711059197, 'idx_start': 841}
# 1198: {'idx_end': 851, 'is_leaf': 0, 'radius': 246.4350624403922, 'idx_start': 846}
# 1201: {'idx_end': 865, 'is_leaf': 0, 'radius': 273.02402824659947, 'idx_start': 860}
# 1202: {'idx_end': 870, 'is_leaf': 0, 'radius': 288.1165736294946, 'idx_start': 865}
# 1204: {'idx_end': 880, 'is_leaf': 0, 'radius': 281.6034800921324, 'idx_start': 875}
# 1205: {'idx_end': 885, 'is_leaf': 0, 'radius': 277.58292454688205, 'idx_start': 880}
# 1206: {'idx_end': 890, 'is_leaf': 0, 'radius': 288.8498571922791, 'idx_start': 885}
# 1207: {'idx_end': 894, 'is_leaf': 0, 'radius': 297.83206257889697, 'idx_start': 890}
# 1210: {'idx_end': 909, 'is_leaf': 0, 'radius': 298.0679788236234, 'idx_start': 904}
# 1211: {'idx_end': 914, 'is_leaf': 0, 'radius': 176.53271651453164, 'idx_start': 909}
# 1212: {'idx_end': 919, 'is_leaf': 0, 'radius': 228.23926042642174, 'idx_start': 914}
# 1214: {'idx_end': 929, 'is_leaf': 0, 'radius': 260.3065884682906, 'idx_start': 924}
# 1219: {'idx_end': 952, 'is_leaf': 0, 'radius': 266.93679027065565, 'idx_start': 948}
# 1224: {'idx_end': 976, 'is_leaf': 0, 'radius': 292.15187830989544, 'idx_start': 971}
# 1226: {'idx_end': 986, 'is_leaf': 0, 'radius': 277.0157396250257, 'idx_start': 981}
# 1227: {'idx_end': 991, 'is_leaf': 0, 'radius': 162.43841910090111, 'idx_start': 986}
# 1229: {'idx_end': 1001, 'is_leaf': 0, 'radius': 177.76242572602348, 'idx_start': 996}
# 1233: {'idx_end': 1020, 'is_leaf': 0, 'radius': 292.936102247572, 'idx_start': 1015}
# 1234: {'idx_end': 1025, 'is_leaf': 0, 'radius': 276.27927899138575, 'idx_start': 1020}
# 1236: {'idx_end': 1035, 'is_leaf': 0, 'radius': 290.42479233013154, 'idx_start': 1030}
# 1239: {'idx_end': 1049, 'is_leaf': 0, 'radius': 261.4703616091124, 'idx_start': 1045}
# 1240: {'idx_end': 1054, 'is_leaf': 0, 'radius': 234.52667225712307, 'idx_start': 1049}
# 1241: {'idx_end': 1059, 'is_leaf': 0, 'radius': 258.7887169101467, 'idx_start': 1054}
# 1243: {'idx_end': 1069, 'is_leaf': 0, 'radius': 202.71191380873498, 'idx_start': 1064}
# 1246: {'idx_end': 1084, 'is_leaf': 0, 'radius': 288.1705744867092, 'idx_start': 1079}
# 1251: {'idx_end': 1107, 'is_leaf': 0, 'radius': 273.49600088483925, 'idx_start': 1103}
# 1252: {'idx_end': 1112, 'is_leaf': 0, 'radius': 290.46376710357526, 'idx_start': 1107}
# 1255: {'idx_end': 1126, 'is_leaf': 0, 'radius': 286.48538357130894, 'idx_start': 1122}
# 1262: {'idx_end': 1161, 'is_leaf': 0, 'radius': 277.01747237313396, 'idx_start': 1156}
# 1263: {'idx_end': 1165, 'is_leaf': 0, 'radius': 287.19005031511796, 'idx_start': 1161}
# 1268: {'idx_end': 1190, 'is_leaf': 0, 'radius': 239.4816068093748, 'idx_start': 1185}
# 1271: {'idx_end': 1204, 'is_leaf': 0, 'radius': 276.70166696281393, 'idx_start': 1200}
# 1272: {'idx_end': 1209, 'is_leaf': 0, 'radius': 290.16374687407114, 'idx_start': 1204}
# 1273: {'idx_end': 1214, 'is_leaf': 0, 'radius': 285.07851550055466, 'idx_start': 1209}
# 1275: {'idx_end': 1224, 'is_leaf': 0, 'radius': 293.6619144526575, 'idx_start': 1219}
# 1276: {'idx_end': 1229, 'is_leaf': 0, 'radius': 140.7410387911074, 'idx_start': 1224}
# 1277: {'idx_end': 1234, 'is_leaf': 0, 'radius': 296.4378518340733, 'idx_start': 1229}
# 1278: {'idx_end': 1239, 'is_leaf': 0, 'radius': 285.74576112341543, 'idx_start': 1234}
# 1292: {'idx_end': 1306, 'is_leaf': 0, 'radius': 292.1194276319191, 'idx_start': 1301}
# 1293: {'idx_end': 1311, 'is_leaf': 0, 'radius': 296.8494567958648, 'idx_start': 1306}
# 1302: {'idx_end': 1354, 'is_leaf': 0, 'radius': 280.32367006729925, 'idx_start': 1349}
# 1310: {'idx_end': 1393, 'is_leaf': 0, 'radius': 266.4121618845506, 'idx_start': 1388}
# 1312: {'idx_end': 1402, 'is_leaf': 0, 'radius': 276.7880055204705, 'idx_start': 1397}
# 1313: {'idx_end': 1407, 'is_leaf': 0, 'radius': 283.7794213821714, 'idx_start': 1402}
# 1317: {'idx_end': 1426, 'is_leaf': 0, 'radius': 290.07854108844384, 'idx_start': 1421}
# 1319: {'idx_end': 1435, 'is_leaf': 0, 'radius': 283.6670583624401, 'idx_start': 1431}
# 1322: {'idx_end': 1450, 'is_leaf': 0, 'radius': 249.8230573826203, 'idx_start': 1445}
# 1324: {'idx_end': 1460, 'is_leaf': 0, 'radius': 226.28424602698263, 'idx_start': 1455}
# 1325: {'idx_end': 1465, 'is_leaf': 0, 'radius': 232.25339610003547, 'idx_start': 1460}
# 1326: {'idx_end': 1470, 'is_leaf': 0, 'radius': 261.28459579546586, 'idx_start': 1465}
# 1327: {'idx_end': 1474, 'is_leaf': 0, 'radius': 182.15995718049564, 'idx_start': 1470}
# 1328: {'idx_end': 1479, 'is_leaf': 0, 'radius': 282.4618912349062, 'idx_start': 1474}
# 1329: {'idx_end': 1484, 'is_leaf': 0, 'radius': 265.46133428429835, 'idx_start': 1479}
# 1330: {'idx_end': 1489, 'is_leaf': 0, 'radius': 239.53246126569152, 'idx_start': 1484}
# 1331: {'idx_end': 1494, 'is_leaf': 0, 'radius': 215.91683584195093, 'idx_start': 1489}
# 1333: {'idx_end': 1504, 'is_leaf': 0, 'radius': 280.3260244786416, 'idx_start': 1499}
# 1334: {'idx_end': 1509, 'is_leaf': 0, 'radius': 274.6329914631525, 'idx_start': 1504}
# 1338: {'idx_end': 1528, 'is_leaf': 0, 'radius': 214.9985116227552, 'idx_start': 1523}
# 1340: {'idx_end': 1538, 'is_leaf': 0, 'radius': 267.32721522508706, 'idx_start': 1533}
# 1347: {'idx_end': 1571, 'is_leaf': 0, 'radius': 296.4973650810408, 'idx_start': 1567}
# 1351: {'idx_end': 1590, 'is_leaf': 0, 'radius': 266.60797531206754, 'idx_start': 1586}
# 1353: {'idx_end': 1600, 'is_leaf': 0, 'radius': 243.0297924123707, 'idx_start': 1595}
# 1355: {'idx_end': 1610, 'is_leaf': 0, 'radius': 273.57236702561903, 'idx_start': 1605}
# 1356: {'idx_end': 1615, 'is_leaf': 0, 'radius': 292.237916773303, 'idx_start': 1610}
# 1365: {'idx_end': 1659, 'is_leaf': 0, 'radius': 186.2033297231819, 'idx_start': 1654}
# 1366: {'idx_end': 1664, 'is_leaf': 0, 'radius': 277.6255031512774, 'idx_start': 1659}
# 1369: {'idx_end': 1678, 'is_leaf': 0, 'radius': 256.29966835717914, 'idx_start': 1673}
# 1375: {'idx_end': 1707, 'is_leaf': 0, 'radius': 236.39149202118082, 'idx_start': 1703}
# 1376: {'idx_end': 1712, 'is_leaf': 0, 'radius': 271.79116983448887, 'idx_start': 1707}
# 1378: {'idx_end': 1722, 'is_leaf': 0, 'radius': 237.36107515765934, 'idx_start': 1717}
# 1379: {'idx_end': 1726, 'is_leaf': 0, 'radius': 261.07925042025073, 'idx_start': 1722}
# 1380: {'idx_end': 1731, 'is_leaf': 0, 'radius': 279.21138945250794, 'idx_start': 1726}
# 1381: {'idx_end': 1736, 'is_leaf': 0, 'radius': 268.7331017943267, 'idx_start': 1731}
# 1383: {'idx_end': 1745, 'is_leaf': 0, 'radius': 265.96604576524425, 'idx_start': 1741}
# 1385: {'idx_end': 1755, 'is_leaf': 0, 'radius': 262.55673672560755, 'idx_start': 1750}
# 1386: {'idx_end': 1760, 'is_leaf': 0, 'radius': 168.58006999642635, 'idx_start': 1755}
# 1388: {'idx_end': 1770, 'is_leaf': 0, 'radius': 149.08856428311327, 'idx_start': 1765}
# 1389: {'idx_end': 1775, 'is_leaf': 0, 'radius': 242.6474809265491, 'idx_start': 1770}
# 1393: {'idx_end': 1794, 'is_leaf': 0, 'radius': 294.6025797578833, 'idx_start': 1789}
# 1394: {'idx_end': 1799, 'is_leaf': 0, 'radius': 282.4383826607142, 'idx_start': 1794}
# 1395: {'idx_end': 1804, 'is_leaf': 0, 'radius': 142.29167227916042, 'idx_start': 1799}
# 1396: {'idx_end': 1809, 'is_leaf': 0, 'radius': 159.6511196327793, 'idx_start': 1804}
# 1399: {'idx_end': 1823, 'is_leaf': 0, 'radius': 214.4312244054023, 'idx_start': 1819}
# 1401: {'idx_end': 1833, 'is_leaf': 0, 'radius': 247.14789094791, 'idx_start': 1828}
# 1404: {'idx_end': 1848, 'is_leaf': 0, 'radius': 289.796342281955, 'idx_start': 1843}
# 1406: {'idx_end': 1858, 'is_leaf': 0, 'radius': 287.7669890727566, 'idx_start': 1853}
# 1409: {'idx_end': 1872, 'is_leaf': 0, 'radius': 292.0667731872286, 'idx_start': 1867}
# 1412: {'idx_end': 1886, 'is_leaf': 0, 'radius': 287.2436596341161, 'idx_start': 1881}
# 1413: {'idx_end': 1891, 'is_leaf': 0, 'radius': 238.87302066160586, 'idx_start': 1886}
# 1414: {'idx_end': 1896, 'is_leaf': 0, 'radius': 239.81542902824245, 'idx_start': 1891}
# 1418: {'idx_end': 1915, 'is_leaf': 0, 'radius': 288.0419413904857, 'idx_start': 1910}
# 1419: {'idx_end': 1920, 'is_leaf': 0, 'radius': 281.3564287518592, 'idx_start': 1915}
# 1422: {'idx_end': 1935, 'is_leaf': 0, 'radius': 288.07644818693535, 'idx_start': 1930}
# 1423: {'idx_end': 1939, 'is_leaf': 0, 'radius': 297.44001496100014, 'idx_start': 1935}
# 1425: {'idx_end': 1949, 'is_leaf': 0, 'radius': 296.0444561210359, 'idx_start': 1944}
# 1428: {'idx_end': 1964, 'is_leaf': 0, 'radius': 221.42628570248837, 'idx_start': 1959}
# 1429: {'idx_end': 1969, 'is_leaf': 0, 'radius': 296.45674220702085, 'idx_start': 1964}
# 1431: {'idx_end': 1978, 'is_leaf': 0, 'radius': 248.6444499682227, 'idx_start': 1974}
# 1433: {'idx_end': 1988, 'is_leaf': 0, 'radius': 295.50357019839873, 'idx_start': 1983}
# 1434: {'idx_end': 1993, 'is_leaf': 0, 'radius': 243.25427026056505, 'idx_start': 1988}
# 1440: {'idx_end': 2022, 'is_leaf': 0, 'radius': 293.8091897813954, 'idx_start': 2017}
# 1443: {'idx_end': 2036, 'is_leaf': 0, 'radius': 261.15022017988036, 'idx_start': 2032}
# 1447: {'idx_end': 2055, 'is_leaf': 0, 'radius': 261.4666565740267, 'idx_start': 2051}
# 1448: {'idx_end': 2060, 'is_leaf': 0, 'radius': 287.6976885551916, 'idx_start': 2055}
# 1449: {'idx_end': 2065, 'is_leaf': 0, 'radius': 261.37658655663864, 'idx_start': 2060}
# 1450: {'idx_end': 2070, 'is_leaf': 0, 'radius': 268.33016975360783, 'idx_start': 2065}
# 1451: {'idx_end': 2075, 'is_leaf': 0, 'radius': 201.33126930509326, 'idx_start': 2070}
# 1452: {'idx_end': 2080, 'is_leaf': 0, 'radius': 241.85938063263123, 'idx_start': 2075}
# 1453: {'idx_end': 2085, 'is_leaf': 0, 'radius': 216.1658622447125, 'idx_start': 2080}
# 1454: {'idx_end': 2090, 'is_leaf': 0, 'radius': 208.54927475299453, 'idx_start': 2085}
# 1457: {'idx_end': 2104, 'is_leaf': 0, 'radius': 204.5653929676279, 'idx_start': 2099}
# 1458: {'idx_end': 2109, 'is_leaf': 0, 'radius': 252.4752661153167, 'idx_start': 2104}
# 1459: {'idx_end': 2114, 'is_leaf': 0, 'radius': 283.1477352902544, 'idx_start': 2109}
# 1460: {'idx_end': 2119, 'is_leaf': 0, 'radius': 275.34044381456204, 'idx_start': 2114}
# 1462: {'idx_end': 2129, 'is_leaf': 0, 'radius': 288.1995836221835, 'idx_start': 2124}
# 1466: {'idx_end': 2148, 'is_leaf': 0, 'radius': 282.62193828505247, 'idx_start': 2143}
# 1469: {'idx_end': 2163, 'is_leaf': 0, 'radius': 288.6855036194232, 'idx_start': 2158}
# 1470: {'idx_end': 2168, 'is_leaf': 0, 'radius': 240.44317415971696, 'idx_start': 2163}
# 1473: {'idx_end': 2182, 'is_leaf': 0, 'radius': 213.56760053903307, 'idx_start': 2177}
# 1474: {'idx_end': 2187, 'is_leaf': 0, 'radius': 250.54787965576557, 'idx_start': 2182}
# 1475: {'idx_end': 2191, 'is_leaf': 0, 'radius': 194.53855658968996, 'idx_start': 2187}
# 1476: {'idx_end': 2196, 'is_leaf': 0, 'radius': 242.25622799011796, 'idx_start': 2191}
# 1477: {'idx_end': 2201, 'is_leaf': 0, 'radius': 133.80627787962717, 'idx_start': 2196}
# 1478: {'idx_end': 2206, 'is_leaf': 0, 'radius': 296.0264853015689, 'idx_start': 2201}
# 1479: {'idx_end': 2210, 'is_leaf': 0, 'radius': 294.6690940699414, 'idx_start': 2206}
# 1484: {'idx_end': 2235, 'is_leaf': 0, 'radius': 200.5865399272843, 'idx_start': 2230}
# 1485: {'idx_end': 2240, 'is_leaf': 0, 'radius': 277.5802586640483, 'idx_start': 2235}
# 1486: {'idx_end': 2245, 'is_leaf': 0, 'radius': 289.5498575375232, 'idx_start': 2240}
# 1487: {'idx_end': 2249, 'is_leaf': 0, 'radius': 299.8879999266393, 'idx_start': 2245}
# 1489: {'idx_end': 2259, 'is_leaf': 0, 'radius': 282.56624002169826, 'idx_start': 2254}
# 1490: {'idx_end': 2264, 'is_leaf': 0, 'radius': 199.23563938211456, 'idx_start': 2259}
# 1491: {'idx_end': 2269, 'is_leaf': 0, 'radius': 180.274346483353, 'idx_start': 2264}
# 1492: {'idx_end': 2274, 'is_leaf': 0, 'radius': 204.54398060075007, 'idx_start': 2269}
# 1493: {'idx_end': 2279, 'is_leaf': 0, 'radius': 193.80546947906294, 'idx_start': 2274}
# 1494: {'idx_end': 2284, 'is_leaf': 0, 'radius': 134.92056922500734, 'idx_start': 2279}
# 1495: {'idx_end': 2288, 'is_leaf': 0, 'radius': 220.12013765214667, 'idx_start': 2284}
# 1496: {'idx_end': 2293, 'is_leaf': 0, 'radius': 259.8297134663394, 'idx_start': 2288}
# 1497: {'idx_end': 2298, 'is_leaf': 0, 'radius': 188.65969362850132, 'idx_start': 2293}
# 1498: {'idx_end': 2303, 'is_leaf': 0, 'radius': 259.00239381133144, 'idx_start': 2298}
# 1499: {'idx_end': 2308, 'is_leaf': 0, 'radius': 278.33950492159755, 'idx_start': 2303}
# 1500: {'idx_end': 2313, 'is_leaf': 0, 'radius': 183.17434318157117, 'idx_start': 2308}
# 1501: {'idx_end': 2318, 'is_leaf': 0, 'radius': 265.2558764664791, 'idx_start': 2313}
# 1502: {'idx_end': 2323, 'is_leaf': 0, 'radius': 256.5498781913568, 'idx_start': 2318}
# 1503: {'idx_end': 2327, 'is_leaf': 0, 'radius': 245.94689467443982, 'idx_start': 2323}
# 1504: {'idx_end': 2332, 'is_leaf': 0, 'radius': 256.61886134888834, 'idx_start': 2327}
# 1505: {'idx_end': 2337, 'is_leaf': 0, 'radius': 234.3470930052259, 'idx_start': 2332}
# 1506: {'idx_end': 2342, 'is_leaf': 0, 'radius': 219.6810415124619, 'idx_start': 2337}
# 1507: {'idx_end': 2346, 'is_leaf': 0, 'radius': 271.13326981394226, 'idx_start': 2342}
# 1508: {'idx_end': 2351, 'is_leaf': 0, 'radius': 125.82734202072297, 'idx_start': 2346}
# 1509: {'idx_end': 2356, 'is_leaf': 0, 'radius': 187.12177852938444, 'idx_start': 2351}
# 1510: {'idx_end': 2361, 'is_leaf': 0, 'radius': 129.67065974999898, 'idx_start': 2356}
# 1511: {'idx_end': 2365, 'is_leaf': 0, 'radius': 291.52079685675943, 'idx_start': 2361}
# 1512: {'idx_end': 2370, 'is_leaf': 0, 'radius': 211.73577874322515, 'idx_start': 2365}
# 1514: {'idx_end': 2380, 'is_leaf': 0, 'radius': 172.8781073473446, 'idx_start': 2375}
# 1515: {'idx_end': 2385, 'is_leaf': 0, 'radius': 247.37243177039755, 'idx_start': 2380}
# 1516: {'idx_end': 2390, 'is_leaf': 0, 'radius': 127.18946497253616, 'idx_start': 2385}
# 1517: {'idx_end': 2395, 'is_leaf': 0, 'radius': 199.16415340115802, 'idx_start': 2390}
# 1518: {'idx_end': 2400, 'is_leaf': 0, 'radius': 290.79532320861, 'idx_start': 2395}
# 1519: {'idx_end': 2404, 'is_leaf': 0, 'radius': 266.44945580728813, 'idx_start': 2400}
# 1520: {'idx_end': 2409, 'is_leaf': 0, 'radius': 251.72484978642848, 'idx_start': 2404}
# 1521: {'idx_end': 2414, 'is_leaf': 0, 'radius': 231.4442481462868, 'idx_start': 2409}
# 1522: {'idx_end': 2419, 'is_leaf': 0, 'radius': 216.89379889706396, 'idx_start': 2414}
# 1523: {'idx_end': 2424, 'is_leaf': 0, 'radius': 250.00599992800176, 'idx_start': 2419}
# 1524: {'idx_end': 2429, 'is_leaf': 0, 'radius': 228.07814450315053, 'idx_start': 2424}
# 1525: {'idx_end': 2434, 'is_leaf': 0, 'radius': 237.53879683117032, 'idx_start': 2429}
# 1526: {'idx_end': 2439, 'is_leaf': 0, 'radius': 199.31572943448288, 'idx_start': 2434}
# 1527: {'idx_end': 2443, 'is_leaf': 0, 'radius': 215.11130839637417, 'idx_start': 2439}
# 1528: {'idx_end': 2448, 'is_leaf': 0, 'radius': 283.55338121771706, 'idx_start': 2443}
# 1529: {'idx_end': 2453, 'is_leaf': 0, 'radius': 209.60410301327593, 'idx_start': 2448}
# 1530: {'idx_end': 2458, 'is_leaf': 0, 'radius': 175.69564593352908, 'idx_start': 2453}
# 1531: {'idx_end': 2463, 'is_leaf': 0, 'radius': 205.82468267921612, 'idx_start': 2458}
# 1532: {'idx_end': 2468, 'is_leaf': 0, 'radius': 234.20708785175566, 'idx_start': 2463}
# 1533: {'idx_end': 2473, 'is_leaf': 0, 'radius': 239.89972905361938, 'idx_start': 2468}
# 1534: {'idx_end': 2478, 'is_leaf': 0, 'radius': 212.68906883053484, 'idx_start': 2473}
# 1541: {'idx_end': 2511, 'is_leaf': 0, 'radius': 250.02567868121068, 'idx_start': 2506}
# 1543: {'idx_end': 2520, 'is_leaf': 0, 'radius': 290.69743720920553, 'idx_start': 2516}
# 1547: {'idx_end': 2540, 'is_leaf': 0, 'radius': 277.59538901069675, 'idx_start': 2535}
# 1549: {'idx_end': 2550, 'is_leaf': 0, 'radius': 153.00169933696816, 'idx_start': 2545}
# 1551: {'idx_end': 2559, 'is_leaf': 0, 'radius': 290.12303424581785, 'idx_start': 2555}
# 1555: {'idx_end': 2578, 'is_leaf': 0, 'radius': 266.9788147025902, 'idx_start': 2574}
# 1567: {'idx_end': 2636, 'is_leaf': 0, 'radius': 278.4737420296571, 'idx_start': 2632}
# 1571: {'idx_end': 2655, 'is_leaf': 0, 'radius': 297.029880651762, 'idx_start': 2651}
# 1577: {'idx_end': 2684, 'is_leaf': 0, 'radius': 288.3935505520191, 'idx_start': 2679}
# 1580: {'idx_end': 2699, 'is_leaf': 0, 'radius': 298.45944448115546, 'idx_start': 2694}
# 1583: {'idx_end': 2713, 'is_leaf': 0, 'radius': 285.9416461448035, 'idx_start': 2709}
# 1587: {'idx_end': 2733, 'is_leaf': 0, 'radius': 268.0340276905155, 'idx_start': 2728}
# 1589: {'idx_end': 2743, 'is_leaf': 0, 'radius': 291.6956633205231, 'idx_start': 2738}
# 1591: {'idx_end': 2752, 'is_leaf': 0, 'radius': 281.0718324556909, 'idx_start': 2748}
# 1593: {'idx_end': 2762, 'is_leaf': 0, 'radius': 210.11139902442227, 'idx_start': 2757}
# 1594: {'idx_end': 2767, 'is_leaf': 0, 'radius': 275.33419693165615, 'idx_start': 2762}
# 1595: {'idx_end': 2772, 'is_leaf': 0, 'radius': 264.4512809573816, 'idx_start': 2767}
# 1597: {'idx_end': 2782, 'is_leaf': 0, 'radius': 294.3627014416059, 'idx_start': 2777}
# 1598: {'idx_end': 2787, 'is_leaf': 0, 'radius': 272.40528629231846, 'idx_start': 2782}
# 1607: {'idx_end': 2829, 'is_leaf': 0, 'radius': 156.38693999180367, 'idx_start': 2825}
# 1611: {'idx_end': 2849, 'is_leaf': 0, 'radius': 291.40219628547754, 'idx_start': 2844}
# 1617: {'idx_end': 2878, 'is_leaf': 0, 'radius': 267.2955667421366, 'idx_start': 2873}
# 1625: {'idx_end': 2917, 'is_leaf': 0, 'radius': 292.4497221745988, 'idx_start': 2912}
# 1627: {'idx_end': 2927, 'is_leaf': 0, 'radius': 295.91992160042213, 'idx_start': 2922}
# 1629: {'idx_end': 2937, 'is_leaf': 0, 'radius': 294.0189109564212, 'idx_start': 2932}
# 1635: {'idx_end': 2965, 'is_leaf': 0, 'radius': 246.51888872863273, 'idx_start': 2961}
# 1638: {'idx_end': 2980, 'is_leaf': 0, 'radius': 295.42200324281873, 'idx_start': 2975}
# 1640: {'idx_end': 2989, 'is_leaf': 0, 'radius': 279.5537873111362, 'idx_start': 2984}
# 1644: {'idx_end': 3009, 'is_leaf': 0, 'radius': 275.22434485343047, 'idx_start': 3004}
# 1646: {'idx_end': 3019, 'is_leaf': 0, 'radius': 255.86394822248798, 'idx_start': 3014}
# 1649: {'idx_end': 3033, 'is_leaf': 0, 'radius': 290.89262623861754, 'idx_start': 3028}
# 1651: {'idx_end': 3043, 'is_leaf': 0, 'radius': 281.76302099459394, 'idx_start': 3038}
# 1652: {'idx_end': 3048, 'is_leaf': 0, 'radius': 264.2143826516641, 'idx_start': 3043}
# 1653: {'idx_end': 3053, 'is_leaf': 0, 'radius': 264.27016479353097, 'idx_start': 3048}
# 1654: {'idx_end': 3058, 'is_leaf': 0, 'radius': 264.4830429347032, 'idx_start': 3053}
# 1656: {'idx_end': 3067, 'is_leaf': 0, 'radius': 216.12302052303454, 'idx_start': 3062}
# 1661: {'idx_end': 3092, 'is_leaf': 0, 'radius': 279.6562890406723, 'idx_start': 3087}
# 1665: {'idx_end': 3111, 'is_leaf': 0, 'radius': 268.8359350979701, 'idx_start': 3106}
# 1666: {'idx_end': 3116, 'is_leaf': 0, 'radius': 287.6629972728506, 'idx_start': 3111}
# 1668: {'idx_end': 3125, 'is_leaf': 0, 'radius': 281.2917346812735, 'idx_start': 3120}
# 1669: {'idx_end': 3130, 'is_leaf': 0, 'radius': 196.88616000115397, 'idx_start': 3125}
# 1674: {'idx_end': 3154, 'is_leaf': 0, 'radius': 293.39352412757853, 'idx_start': 3149}
# 1676: {'idx_end': 3164, 'is_leaf': 0, 'radius': 229.3393991445866, 'idx_start': 3159}
# 1677: {'idx_end': 3169, 'is_leaf': 0, 'radius': 198.01979699009894, 'idx_start': 3164}
# 1678: {'idx_end': 3174, 'is_leaf': 0, 'radius': 266.7493955007209, 'idx_start': 3169}
# 1679: {'idx_end': 3178, 'is_leaf': 0, 'radius': 251.56522514051898, 'idx_start': 3174}
# 1685: {'idx_end': 3208, 'is_leaf': 0, 'radius': 92.47096841711998, 'idx_start': 3203}
# 1687: {'idx_end': 3217, 'is_leaf': 0, 'radius': 192.41118080818484, 'idx_start': 3213}
# 1688: {'idx_end': 3222, 'is_leaf': 0, 'radius': 134.41339218991536, 'idx_start': 3217}
# 1689: {'idx_end': 3227, 'is_leaf': 0, 'radius': 117.60170066797502, 'idx_start': 3222}
# 1690: {'idx_end': 3232, 'is_leaf': 0, 'radius': 133.03007178829907, 'idx_start': 3227}
# 1691: {'idx_end': 3237, 'is_leaf': 0, 'radius': 259.84064347210966, 'idx_start': 3232}
# 1693: {'idx_end': 3247, 'is_leaf': 0, 'radius': 234.64253663818081, 'idx_start': 3242}
# 1694: {'idx_end': 3252, 'is_leaf': 0, 'radius': 277.7871127320344, 'idx_start': 3247}
# 1699: {'idx_end': 3275, 'is_leaf': 0, 'radius': 204.5128357829894, 'idx_start': 3271}
# 1703: {'idx_end': 3294, 'is_leaf': 0, 'radius': 206.74032625494235, 'idx_start': 3290}
# 1704: {'idx_end': 3299, 'is_leaf': 0, 'radius': 148.26894482662243, 'idx_start': 3294}
# 1705: {'idx_end': 3304, 'is_leaf': 0, 'radius': 227.1691880515489, 'idx_start': 3299}
# 1706: {'idx_end': 3309, 'is_leaf': 0, 'radius': 235.30737345013227, 'idx_start': 3304}
# 1710: {'idx_end': 3329, 'is_leaf': 0, 'radius': 287.67801445365967, 'idx_start': 3324}
# 1712: {'idx_end': 3338, 'is_leaf': 0, 'radius': 253.8935209886223, 'idx_start': 3333}
# 1713: {'idx_end': 3343, 'is_leaf': 0, 'radius': 288.40596387730955, 'idx_start': 3338}
# 1716: {'idx_end': 3358, 'is_leaf': 0, 'radius': 286.1753308725265, 'idx_start': 3353}
# 1717: {'idx_end': 3363, 'is_leaf': 0, 'radius': 224.9322564684754, 'idx_start': 3358}
# 1722: {'idx_end': 3387, 'is_leaf': 0, 'radius': 292.77643347783305, 'idx_start': 3382}
# 1729: {'idx_end': 3421, 'is_leaf': 0, 'radius': 193.55681336496528, 'idx_start': 3416}
# 1731: {'idx_end': 3430, 'is_leaf': 0, 'radius': 158.9488911568747, 'idx_start': 3426}
# 1733: {'idx_end': 3440, 'is_leaf': 0, 'radius': 271.232962598575, 'idx_start': 3435}
# 1734: {'idx_end': 3445, 'is_leaf': 0, 'radius': 212.37448057617468, 'idx_start': 3440}
# 1735: {'idx_end': 3449, 'is_leaf': 0, 'radius': 197.20595198928453, 'idx_start': 3445}
# 1736: {'idx_end': 3454, 'is_leaf': 0, 'radius': 138.67660220815912, 'idx_start': 3449}
# 1737: {'idx_end': 3459, 'is_leaf': 0, 'radius': 238.445549339886, 'idx_start': 3454}
# 1738: {'idx_end': 3464, 'is_leaf': 0, 'radius': 201.5354063185921, 'idx_start': 3459}
# 1739: {'idx_end': 3469, 'is_leaf': 0, 'radius': 115.97154823490112, 'idx_start': 3464}
# 1740: {'idx_end': 3474, 'is_leaf': 0, 'radius': 183.6663278883748, 'idx_start': 3469}
# 1741: {'idx_end': 3479, 'is_leaf': 0, 'radius': 276.8524516777845, 'idx_start': 3474}
# 1742: {'idx_end': 3484, 'is_leaf': 0, 'radius': 126.34967352549829, 'idx_start': 3479}
# 1743: {'idx_end': 3488, 'is_leaf': 0, 'radius': 131.15568039547506, 'idx_start': 3484}
# 1744: {'idx_end': 3493, 'is_leaf': 0, 'radius': 260.38771092353807, 'idx_start': 3488}
# 1745: {'idx_end': 3498, 'is_leaf': 0, 'radius': 247.49472721656113, 'idx_start': 3493}
# 1746: {'idx_end': 3503, 'is_leaf': 0, 'radius': 274.6092496621335, 'idx_start': 3498}
# 1747: {'idx_end': 3508, 'is_leaf': 0, 'radius': 272.1246038122977, 'idx_start': 3503}
# 1748: {'idx_end': 3513, 'is_leaf': 0, 'radius': 274.4212090928833, 'idx_start': 3508}
# 1749: {'idx_end': 3518, 'is_leaf': 0, 'radius': 267.9926118384609, 'idx_start': 3513}
# 1750: {'idx_end': 3523, 'is_leaf': 0, 'radius': 225.36947441923016, 'idx_start': 3518}
# 1753: {'idx_end': 3537, 'is_leaf': 0, 'radius': 160.9771412344001, 'idx_start': 3532}
# 1754: {'idx_end': 3542, 'is_leaf': 0, 'radius': 293.86323349476714, 'idx_start': 3537}
# 1755: {'idx_end': 3547, 'is_leaf': 0, 'radius': 296.1715043686681, 'idx_start': 3542}
# 1758: {'idx_end': 3562, 'is_leaf': 0, 'radius': 284.47467374091497, 'idx_start': 3557}
# 1759: {'idx_end': 3566, 'is_leaf': 0, 'radius': 170.0845378039991, 'idx_start': 3562}
# 1760: {'idx_end': 3571, 'is_leaf': 0, 'radius': 207.53814107291217, 'idx_start': 3566}
# 1761: {'idx_end': 3576, 'is_leaf': 0, 'radius': 260.20353571771466, 'idx_start': 3571}
# 1762: {'idx_end': 3581, 'is_leaf': 0, 'radius': 295.781541006196, 'idx_start': 3576}
# 1763: {'idx_end': 3585, 'is_leaf': 0, 'radius': 243.1587701482305, 'idx_start': 3581}
# 1766: {'idx_end': 3600, 'is_leaf': 0, 'radius': 287.93276993076006, 'idx_start': 3595}
# 1767: {'idx_end': 3604, 'is_leaf': 0, 'radius': 278.47138542406833, 'idx_start': 3600}
# 1768: {'idx_end': 3609, 'is_leaf': 0, 'radius': 291.1754797368763, 'idx_start': 3604}
# 1769: {'idx_end': 3614, 'is_leaf': 0, 'radius': 275.40479298661455, 'idx_start': 3609}
# 1770: {'idx_end': 3619, 'is_leaf': 0, 'radius': 143.80598040415427, 'idx_start': 3614}
# 1771: {'idx_end': 3624, 'is_leaf': 0, 'radius': 262.92614932714474, 'idx_start': 3619}
# 1772: {'idx_end': 3629, 'is_leaf': 0, 'radius': 272.96952210823827, 'idx_start': 3624}
# 1773: {'idx_end': 3634, 'is_leaf': 0, 'radius': 193.8625286124165, 'idx_start': 3629}
# 1774: {'idx_end': 3639, 'is_leaf': 0, 'radius': 156.88913282952396, 'idx_start': 3634}
# 1775: {'idx_end': 3643, 'is_leaf': 0, 'radius': 241.33288731542578, 'idx_start': 3639}
# 1776: {'idx_end': 3648, 'is_leaf': 0, 'radius': 281.5920453421935, 'idx_start': 3643}
# 1778: {'idx_end': 3658, 'is_leaf': 0, 'radius': 277.09406345138467, 'idx_start': 3653}
# 1779: {'idx_end': 3663, 'is_leaf': 0, 'radius': 298.05670601414096, 'idx_start': 3658}
# 1781: {'idx_end': 3673, 'is_leaf': 0, 'radius': 293.49821123816065, 'idx_start': 3668}
# 1782: {'idx_end': 3678, 'is_leaf': 0, 'radius': 256.7817750542277, 'idx_start': 3673}
# 1783: {'idx_end': 3682, 'is_leaf': 0, 'radius': 216.8431172530039, 'idx_start': 3678}
# 1786: {'idx_end': 3697, 'is_leaf': 0, 'radius': 242.4701218707163, 'idx_start': 3692}
# 1787: {'idx_end': 3702, 'is_leaf': 0, 'radius': 156.99070036151824, 'idx_start': 3697}
# 1788: {'idx_end': 3707, 'is_leaf': 0, 'radius': 230.10971296318635, 'idx_start': 3702}
# 1789: {'idx_end': 3712, 'is_leaf': 0, 'radius': 250.93847851614944, 'idx_start': 3707}
# 1790: {'idx_end': 3717, 'is_leaf': 0, 'radius': 238.2284617756661, 'idx_start': 3712}
# 1791: {'idx_end': 3721, 'is_leaf': 0, 'radius': 153.35742564349468, 'idx_start': 3717}
# 1792: {'idx_end': 3726, 'is_leaf': 0, 'radius': 271.1940264828855, 'idx_start': 3721}
# 1793: {'idx_end': 3731, 'is_leaf': 0, 'radius': 139.14481664798012, 'idx_start': 3726}
# 1794: {'idx_end': 3736, 'is_leaf': 0, 'radius': 195.09464369889804, 'idx_start': 3731}
# 1795: {'idx_end': 3740, 'is_leaf': 0, 'radius': 281.4247235052386, 'idx_start': 3736}
# 1796: {'idx_end': 3745, 'is_leaf': 0, 'radius': 125.40749578872867, 'idx_start': 3740}
# 1797: {'idx_end': 3750, 'is_leaf': 0, 'radius': 116.18622982092154, 'idx_start': 3745}
# 1798: {'idx_end': 3755, 'is_leaf': 0, 'radius': 196.82957094908275, 'idx_start': 3750}
# 1799: {'idx_end': 3759, 'is_leaf': 0, 'radius': 297.38243475363504, 'idx_start': 3755}
# 1800: {'idx_end': 3764, 'is_leaf': 0, 'radius': 205.4681483831496, 'idx_start': 3759}
# 1801: {'idx_end': 3769, 'is_leaf': 0, 'radius': 274.77576312331473, 'idx_start': 3764}
# 1802: {'idx_end': 3774, 'is_leaf': 0, 'radius': 190.41365497253605, 'idx_start': 3769}
# 1803: {'idx_end': 3779, 'is_leaf': 0, 'radius': 237.04969943030935, 'idx_start': 3774}
# 1804: {'idx_end': 3784, 'is_leaf': 0, 'radius': 219.70197996376822, 'idx_start': 3779}
# 1805: {'idx_end': 3789, 'is_leaf': 0, 'radius': 275.770121659327, 'idx_start': 3784}
# 1807: {'idx_end': 3798, 'is_leaf': 0, 'radius': 290.98206559855197, 'idx_start': 3794}
# 1808: {'idx_end': 3803, 'is_leaf': 0, 'radius': 255.57026431101093, 'idx_start': 3798}
# 1809: {'idx_end': 3808, 'is_leaf': 0, 'radius': 278.0913518971779, 'idx_start': 3803}
# 1810: {'idx_end': 3813, 'is_leaf': 0, 'radius': 199.71059060550593, 'idx_start': 3808}
# 1811: {'idx_end': 3817, 'is_leaf': 0, 'radius': 293.74670210914707, 'idx_start': 3813}
# 1813: {'idx_end': 3827, 'is_leaf': 0, 'radius': 283.9094926204477, 'idx_start': 3822}
# 1814: {'idx_end': 3832, 'is_leaf': 0, 'radius': 270.37270572304453, 'idx_start': 3827}
# 1815: {'idx_end': 3836, 'is_leaf': 0, 'radius': 179.35108725625278, 'idx_start': 3832}
# 1816: {'idx_end': 3841, 'is_leaf': 0, 'radius': 202.1725006028268, 'idx_start': 3836}
# 1818: {'idx_end': 3851, 'is_leaf': 0, 'radius': 217.88832001738865, 'idx_start': 3846}
# 1819: {'idx_end': 3856, 'is_leaf': 0, 'radius': 292.5660950964755, 'idx_start': 3851}
# 1820: {'idx_end': 3861, 'is_leaf': 0, 'radius': 168.34203277850722, 'idx_start': 3856}
# 1821: {'idx_end': 3866, 'is_leaf': 0, 'radius': 126.7670304140631, 'idx_start': 3861}
# 1824: {'idx_end': 3880, 'is_leaf': 0, 'radius': 151.9127381097451, 'idx_start': 3875}
# 1826: {'idx_end': 3890, 'is_leaf': 0, 'radius': 216.3969500709287, 'idx_start': 3885}
# 1827: {'idx_end': 3894, 'is_leaf': 0, 'radius': 131.27475956938562, 'idx_start': 3890}
# 1828: {'idx_end': 3899, 'is_leaf': 0, 'radius': 147.30349622463143, 'idx_start': 3894}
# 1829: {'idx_end': 3904, 'is_leaf': 0, 'radius': 254.62136595344867, 'idx_start': 3899}
# 1830: {'idx_end': 3909, 'is_leaf': 0, 'radius': 280.189578678437, 'idx_start': 3904}
# 1831: {'idx_end': 3913, 'is_leaf': 0, 'radius': 288.49209261260523, 'idx_start': 3909}
# 1832: {'idx_end': 3918, 'is_leaf': 0, 'radius': 145.23305408893663, 'idx_start': 3913}
# 1833: {'idx_end': 3923, 'is_leaf': 0, 'radius': 235.08407006856078, 'idx_start': 3918}
# 1834: {'idx_end': 3928, 'is_leaf': 0, 'radius': 221.14402546756713, 'idx_start': 3923}
# 1835: {'idx_end': 3933, 'is_leaf': 0, 'radius': 242.318798280282, 'idx_start': 3928}
# 1836: {'idx_end': 3938, 'is_leaf': 0, 'radius': 143.1216265977997, 'idx_start': 3933}
# 1837: {'idx_end': 3943, 'is_leaf': 0, 'radius': 227.42594399056586, 'idx_start': 3938}
# 1838: {'idx_end': 3948, 'is_leaf': 0, 'radius': 177.47484328771785, 'idx_start': 3943}
# 1839: {'idx_end': 3952, 'is_leaf': 0, 'radius': 234.0937312274722, 'idx_start': 3948}
# 1840: {'idx_end': 3957, 'is_leaf': 0, 'radius': 247.96935294507662, 'idx_start': 3952}
# 1841: {'idx_end': 3962, 'is_leaf': 0, 'radius': 283.2871334882684, 'idx_start': 3957}
# 1843: {'idx_end': 3972, 'is_leaf': 0, 'radius': 204.37485168190338, 'idx_start': 3967}
# 1845: {'idx_end': 3982, 'is_leaf': 0, 'radius': 131.14434795293315, 'idx_start': 3977}
# 1848: {'idx_end': 3996, 'is_leaf': 0, 'radius': 299.27051308139266, 'idx_start': 3991}
# 1849: {'idx_end': 4001, 'is_leaf': 0, 'radius': 251.52797061162008, 'idx_start': 3996}
# 1850: {'idx_end': 4006, 'is_leaf': 0, 'radius': 277.78099287028255, 'idx_start': 4001}
# 1852: {'idx_end': 4016, 'is_leaf': 0, 'radius': 174.2962994443657, 'idx_start': 4011}
# 1854: {'idx_end': 4026, 'is_leaf': 0, 'radius': 296.8049864810226, 'idx_start': 4021}
# 1856: {'idx_end': 4035, 'is_leaf': 0, 'radius': 274.27059630955705, 'idx_start': 4030}
# 1859: {'idx_end': 4049, 'is_leaf': 0, 'radius': 274.71007444212887, 'idx_start': 4045}
# 1860: {'idx_end': 4054, 'is_leaf': 0, 'radius': 237.75314929565084, 'idx_start': 4049}
# 1861: {'idx_end': 4059, 'is_leaf': 0, 'radius': 270.25018038846895, 'idx_start': 4054}
# 1862: {'idx_end': 4064, 'is_leaf': 0, 'radius': 294.7293673864211, 'idx_start': 4059}
# 1863: {'idx_end': 4068, 'is_leaf': 0, 'radius': 283.3714435153973, 'idx_start': 4064}
# 1864: {'idx_end': 4073, 'is_leaf': 0, 'radius': 280.65993657805893, 'idx_start': 4068}
# 1866: {'idx_end': 4083, 'is_leaf': 0, 'radius': 274.7223325468827, 'idx_start': 4078}
# 1867: {'idx_end': 4088, 'is_leaf': 0, 'radius': 277.7200748955682, 'idx_start': 4083}
# 1868: {'idx_end': 4093, 'is_leaf': 0, 'radius': 253.35003453719915, 'idx_start': 4088}
# 1870: {'idx_end': 4103, 'is_leaf': 0, 'radius': 264.0627198223937, 'idx_start': 4098}
# 1871: {'idx_end': 4107, 'is_leaf': 0, 'radius': 288.28024559445623, 'idx_start': 4103}
# 1873: {'idx_end': 4117, 'is_leaf': 0, 'radius': 205.714753967721, 'idx_start': 4112}
# 1875: {'idx_end': 4127, 'is_leaf': 0, 'radius': 276.48877011553293, 'idx_start': 4122}
# 1876: {'idx_end': 4132, 'is_leaf': 0, 'radius': 254.55207718657496, 'idx_start': 4127}
# 1877: {'idx_end': 4137, 'is_leaf': 0, 'radius': 294.3476176224296, 'idx_start': 4132}
# 1878: {'idx_end': 4142, 'is_leaf': 0, 'radius': 251.81675877510614, 'idx_start': 4137}
# 1879: {'idx_end': 4146, 'is_leaf': 0, 'radius': 220.3507147707944, 'idx_start': 4142}
# 1880: {'idx_end': 4151, 'is_leaf': 0, 'radius': 246.51937043567185, 'idx_start': 4146}
# 1881: {'idx_end': 4156, 'is_leaf': 0, 'radius': 132.25248579894446, 'idx_start': 4151}
# 1882: {'idx_end': 4161, 'is_leaf': 0, 'radius': 216.62834532904503, 'idx_start': 4156}
# 1883: {'idx_end': 4166, 'is_leaf': 0, 'radius': 194.26095850684973, 'idx_start': 4161}
# 1884: {'idx_end': 4171, 'is_leaf': 0, 'radius': 198.87242141634417, 'idx_start': 4166}
# 1885: {'idx_end': 4176, 'is_leaf': 0, 'radius': 202.8147923599263, 'idx_start': 4171}
# 1886: {'idx_end': 4181, 'is_leaf': 0, 'radius': 99.20846738056181, 'idx_start': 4176}
# 1888: {'idx_end': 4190, 'is_leaf': 0, 'radius': 292.5415526040702, 'idx_start': 4185}
# 1890: {'idx_end': 4200, 'is_leaf': 0, 'radius': 292.91083967651315, 'idx_start': 4195}
# 1891: {'idx_end': 4204, 'is_leaf': 0, 'radius': 293.077421511791, 'idx_start': 4200}
# 1892: {'idx_end': 4209, 'is_leaf': 0, 'radius': 290.1206645518379, 'idx_start': 4204}
# 1896: {'idx_end': 4228, 'is_leaf': 0, 'radius': 280.1045519087471, 'idx_start': 4223}
# 1897: {'idx_end': 4233, 'is_leaf': 0, 'radius': 284.4369174351319, 'idx_start': 4228}
# 1899: {'idx_end': 4243, 'is_leaf': 0, 'radius': 239.55341784245118, 'idx_start': 4238}
# 1900: {'idx_end': 4248, 'is_leaf': 0, 'radius': 241.02721837999962, 'idx_start': 4243}
# 1901: {'idx_end': 4253, 'is_leaf': 0, 'radius': 260.7047372028364, 'idx_start': 4248}
# 1903: {'idx_end': 4262, 'is_leaf': 0, 'radius': 281.9998891843754, 'idx_start': 4258}
# 1904: {'idx_end': 4267, 'is_leaf': 0, 'radius': 294.27218692904023, 'idx_start': 4262}
# 1906: {'idx_end': 4277, 'is_leaf': 0, 'radius': 278.22530438477384, 'idx_start': 4272}
# 1907: {'idx_end': 4282, 'is_leaf': 0, 'radius': 297.8090663495656, 'idx_start': 4277}
# 1908: {'idx_end': 4287, 'is_leaf': 0, 'radius': 264.0951343739601, 'idx_start': 4282}
# 1910: {'idx_end': 4297, 'is_leaf': 0, 'radius': 299.5410489398741, 'idx_start': 4292}
# 1914: {'idx_end': 4316, 'is_leaf': 0, 'radius': 267.6103137025926, 'idx_start': 4311}
# 1917: {'idx_end': 4331, 'is_leaf': 0, 'radius': 277.9494918146101, 'idx_start': 4326}
# 1918: {'idx_end': 4336, 'is_leaf': 0, 'radius': 223.33687559379888, 'idx_start': 4331}
# 1920: {'idx_end': 4345, 'is_leaf': 0, 'radius': 271.6711247077981, 'idx_start': 4340}
# 1922: {'idx_end': 4355, 'is_leaf': 0, 'radius': 276.7780338104886, 'idx_start': 4350}
# 1923: {'idx_end': 4359, 'is_leaf': 0, 'radius': 216.2960933535324, 'idx_start': 4355}
# 1924: {'idx_end': 4364, 'is_leaf': 0, 'radius': 214.23006324976896, 'idx_start': 4359}
# 1927: {'idx_end': 4378, 'is_leaf': 0, 'radius': 101.00773485233692, 'idx_start': 4374}
# 1928: {'idx_end': 4383, 'is_leaf': 0, 'radius': 233.90596401118114, 'idx_start': 4378}
# 1929: {'idx_end': 4388, 'is_leaf': 0, 'radius': 274.91525967104843, 'idx_start': 4383}
# 1933: {'idx_end': 4408, 'is_leaf': 0, 'radius': 249.56305816366324, 'idx_start': 4403}
# 1934: {'idx_end': 4413, 'is_leaf': 0, 'radius': 207.4090644113704, 'idx_start': 4408}
# 1935: {'idx_end': 4417, 'is_leaf': 0, 'radius': 80.34768198274297, 'idx_start': 4413}
# 1937: {'idx_end': 4427, 'is_leaf': 0, 'radius': 284.3782692119775, 'idx_start': 4422}
# 1938: {'idx_end': 4432, 'is_leaf': 0, 'radius': 274.300273423123, 'idx_start': 4427}
# 1939: {'idx_end': 4437, 'is_leaf': 0, 'radius': 280.33601267050943, 'idx_start': 4432}
# 1940: {'idx_end': 4442, 'is_leaf': 0, 'radius': 243.58661703796454, 'idx_start': 4437}
# 1941: {'idx_end': 4447, 'is_leaf': 0, 'radius': 269.57114088863443, 'idx_start': 4442}
# 1943: {'idx_end': 4456, 'is_leaf': 0, 'radius': 176.32002155172282, 'idx_start': 4452}
# 1944: {'idx_end': 4461, 'is_leaf': 0, 'radius': 293.787814587331, 'idx_start': 4456}
# 1948: {'idx_end': 4481, 'is_leaf': 0, 'radius': 292.2184799084412, 'idx_start': 4476}
# 1949: {'idx_end': 4486, 'is_leaf': 0, 'radius': 230.5694689242268, 'idx_start': 4481}
# 1951: {'idx_end': 4495, 'is_leaf': 0, 'radius': 279.4856883634652, 'idx_start': 4491}
# 1954: {'idx_end': 4510, 'is_leaf': 0, 'radius': 250.25922560417226, 'idx_start': 4505}
# 1957: {'idx_end': 4524, 'is_leaf': 0, 'radius': 268.8590708903086, 'idx_start': 4519}
# 1959: {'idx_end': 4533, 'is_leaf': 0, 'radius': 299.02017072431755, 'idx_start': 4529}
# 1962: {'idx_end': 4548, 'is_leaf': 0, 'radius': 227.1182951679587, 'idx_start': 4543}
# ...
# 3910: {'idx_end': 4510, 'is_leaf': 1, 'radius': 235.8525904976336, 'idx_start': 4507}
# 3911: {'idx_end': 4512, 'is_leaf': 1, 'radius': 202.80902346789208, 'idx_start': 4510}
# 3912: {'idx_end': 4514, 'is_leaf': 1, 'radius': 212.16444094145464, 'idx_start': 4512}
# 3913: {'idx_end': 4516, 'is_leaf': 1, 'radius': 43.439613257946945, 'idx_start': 4514}
# 3914: {'idx_end': 4519, 'is_leaf': 1, 'radius': 240.45558610456305, 'idx_start': 4516}
# 3915: {'idx_end': 4521, 'is_leaf': 1, 'radius': 199.74984355438178, 'idx_start': 4519}
# 3916: {'idx_end': 4524, 'is_leaf': 1, 'radius': 204.52764007721683, 'idx_start': 4521}
# 3917: {'idx_end': 4526, 'is_leaf': 1, 'radius': 174.88424743240884, 'idx_start': 4524}
# 3918: {'idx_end': 4529, 'is_leaf': 1, 'radius': 247.4635775669264, 'idx_start': 4526}
# 3919: {'idx_end': 4531, 'is_leaf': 1, 'radius': 202.42714738888162, 'idx_start': 4529}
# 3920: {'idx_end': 4533, 'is_leaf': 1, 'radius': 134.1659420270286, 'idx_start': 4531}
# 3921: {'idx_end': 4535, 'is_leaf': 1, 'radius': 193.0200766759769, 'idx_start': 4533}
# 3922: {'idx_end': 4538, 'is_leaf': 1, 'radius': 274.2063294512202, 'idx_start': 4535}
# 3923: {'idx_end': 4540, 'is_leaf': 1, 'radius': 213.39575909562964, 'idx_start': 4538}
# 3924: {'idx_end': 4543, 'is_leaf': 1, 'radius': 277.4516974978608, 'idx_start': 4540}
# 3925: {'idx_end': 4545, 'is_leaf': 1, 'radius': 140.1079940617237, 'idx_start': 4543}
# 3926: {'idx_end': 4548, 'is_leaf': 1, 'radius': 196.0779323523062, 'idx_start': 4545}
# 3927: {'idx_end': 4550, 'is_leaf': 1, 'radius': 224.56290878059093, 'idx_start': 4548}
# 3928: {'idx_end': 4553, 'is_leaf': 1, 'radius': 189.0267470785843, 'idx_start': 4550}
# 3929: {'idx_end': 4555, 'is_leaf': 1, 'radius': 189.59825948568198, 'idx_start': 4553}
# 3930: {'idx_end': 4558, 'is_leaf': 1, 'radius': 243.8874968322713, 'idx_start': 4555}
# 3931: {'idx_end': 4560, 'is_leaf': 1, 'radius': 168.82831516069808, 'idx_start': 4558}
# 3932: {'idx_end': 4563, 'is_leaf': 1, 'radius': 231.54865099537463, 'idx_start': 4560}
# 3933: {'idx_end': 4565, 'is_leaf': 1, 'radius': 200.7691460359385, 'idx_start': 4563}
# 3934: {'idx_end': 4568, 'is_leaf': 1, 'radius': 219.75693643457788, 'idx_start': 4565}
# 3935: {'idx_end': 4570, 'is_leaf': 1, 'radius': 204.26147458588466, 'idx_start': 4568}
# 3936: {'idx_end': 4572, 'is_leaf': 1, 'radius': 207.306536317599, 'idx_start': 4570}
# 3937: {'idx_end': 4574, 'is_leaf': 1, 'radius': 74.61735723007081, 'idx_start': 4572}
# 3938: {'idx_end': 4577, 'is_leaf': 1, 'radius': 169.42549985170473, 'idx_start': 4574}
# 3939: {'idx_end': 4579, 'is_leaf': 1, 'radius': 187.89558270486296, 'idx_start': 4577}
# 3940: {'idx_end': 4582, 'is_leaf': 1, 'radius': 241.76871408664752, 'idx_start': 4579}
# 3941: {'idx_end': 4584, 'is_leaf': 1, 'radius': 181.80827813936307, 'idx_start': 4582}
# 3942: {'idx_end': 4587, 'is_leaf': 1, 'radius': 166.31128778421638, 'idx_start': 4584}
# 3943: {'idx_end': 4589, 'is_leaf': 1, 'radius': 191.87430781634106, 'idx_start': 4587}
# 3944: {'idx_end': 4592, 'is_leaf': 1, 'radius': 255.74227478285863, 'idx_start': 4589}
# 3945: {'idx_end': 4594, 'is_leaf': 1, 'radius': 186.10279417569205, 'idx_start': 4592}
# 3946: {'idx_end': 4597, 'is_leaf': 1, 'radius': 219.05732380158196, 'idx_start': 4594}
# 3947: {'idx_end': 4599, 'is_leaf': 1, 'radius': 191.62463307205576, 'idx_start': 4597}
# 3948: {'idx_end': 4602, 'is_leaf': 1, 'radius': 273.2485640909715, 'idx_start': 4599}
# 3949: {'idx_end': 4604, 'is_leaf': 1, 'radius': 224.36354427580252, 'idx_start': 4602}
# 3950: {'idx_end': 4607, 'is_leaf': 1, 'radius': 261.7027575959668, 'idx_start': 4604}
# 3951: {'idx_end': 4609, 'is_leaf': 1, 'radius': 73.80548760085526, 'idx_start': 4607}
# 3952: {'idx_end': 4611, 'is_leaf': 1, 'radius': 208.47062143141417, 'idx_start': 4609}
# 3953: {'idx_end': 4613, 'is_leaf': 1, 'radius': 125.32856817182585, 'idx_start': 4611}
# 3954: {'idx_end': 4616, 'is_leaf': 1, 'radius': 199.9144261372295, 'idx_start': 4613}
# 3955: {'idx_end': 4618, 'is_leaf': 1, 'radius': 190.53674186361013, 'idx_start': 4616}
# 3956: {'idx_end': 4621, 'is_leaf': 1, 'radius': 195.01168056184616, 'idx_start': 4618}
# 3957: {'idx_end': 4623, 'is_leaf': 1, 'radius': 189.02182413679114, 'idx_start': 4621}
# 3958: {'idx_end': 4626, 'is_leaf': 1, 'radius': 249.6241619359438, 'idx_start': 4623}
# 3959: {'idx_end': 4628, 'is_leaf': 1, 'radius': 214.84994763788052, 'idx_start': 4626}
# 3960: {'idx_end': 4631, 'is_leaf': 1, 'radius': 220.41753307958263, 'idx_start': 4628}
# 3961: {'idx_end': 4633, 'is_leaf': 1, 'radius': 128.09761902549164, 'idx_start': 4631}
# 3962: {'idx_end': 4636, 'is_leaf': 1, 'radius': 215.05839000399664, 'idx_start': 4633}
# 3963: {'idx_end': 4638, 'is_leaf': 1, 'radius': 197.40757330963774, 'idx_start': 4636}
# 3964: {'idx_end': 4641, 'is_leaf': 1, 'radius': 233.80737560840308, 'idx_start': 4638}
# 3965: {'idx_end': 4643, 'is_leaf': 1, 'radius': 98.08669634563088, 'idx_start': 4641}
# 3966: {'idx_end': 4646, 'is_leaf': 1, 'radius': 258.6587198091983, 'idx_start': 4643}
# 3967: {'idx_end': 4648, 'is_leaf': 1, 'radius': 210.64424986217878, 'idx_start': 4646}
# 3968: {'idx_end': 4650, 'is_leaf': 1, 'radius': 189.1077735049514, 'idx_start': 4648}
# 3969: {'idx_end': 4652, 'is_leaf': 1, 'radius': 107.46394744285173, 'idx_start': 4650}
# 3970: {'idx_end': 4655, 'is_leaf': 1, 'radius': 235.2074734262404, 'idx_start': 4652}
# 3971: {'idx_end': 4657, 'is_leaf': 1, 'radius': 249.55410235057246, 'idx_start': 4655}
# 3972: {'idx_end': 4660, 'is_leaf': 1, 'radius': 242.57644843086752, 'idx_start': 4657}
# 3973: {'idx_end': 4662, 'is_leaf': 1, 'radius': 168.72462772221488, 'idx_start': 4660}
# 3974: {'idx_end': 4665, 'is_leaf': 1, 'radius': 260.83370607002126, 'idx_start': 4662}
# 3975: {'idx_end': 4667, 'is_leaf': 1, 'radius': 150.69671529266986, 'idx_start': 4665}
# 3976: {'idx_end': 4669, 'is_leaf': 1, 'radius': 177.66471230945103, 'idx_start': 4667}
# 3977: {'idx_end': 4671, 'is_leaf': 1, 'radius': 206.4188702614177, 'idx_start': 4669}
# 3978: {'idx_end': 4674, 'is_leaf': 1, 'radius': 235.77390299465577, 'idx_start': 4671}
# 3979: {'idx_end': 4676, 'is_leaf': 1, 'radius': 187.1543480659747, 'idx_start': 4674}
# 3981: {'idx_end': 4681, 'is_leaf': 1, 'radius': 249.08984322930553, 'idx_start': 4679}
# 3982: {'idx_end': 4684, 'is_leaf': 1, 'radius': 276.3186566267287, 'idx_start': 4681}
# 3983: {'idx_end': 4686, 'is_leaf': 1, 'radius': 263.4895633606766, 'idx_start': 4684}
# 3984: {'idx_end': 4688, 'is_leaf': 1, 'radius': 210.52493914023583, 'idx_start': 4686}
# 3985: {'idx_end': 4690, 'is_leaf': 1, 'radius': 116.3206774395679, 'idx_start': 4688}
# 3986: {'idx_end': 4693, 'is_leaf': 1, 'radius': 258.30171849559537, 'idx_start': 4690}
# 3987: {'idx_end': 4695, 'is_leaf': 1, 'radius': 248.74283909290736, 'idx_start': 4693}
# 3988: {'idx_end': 4698, 'is_leaf': 1, 'radius': 265.1425193279183, 'idx_start': 4695}
# 3989: {'idx_end': 4700, 'is_leaf': 1, 'radius': 165.214254832929, 'idx_start': 4698}
# 3990: {'idx_end': 4703, 'is_leaf': 1, 'radius': 259.76784507196675, 'idx_start': 4700}
# 3991: {'idx_end': 4705, 'is_leaf': 1, 'radius': 247.1381192774599, 'idx_start': 4703}
# 3992: {'idx_end': 4708, 'is_leaf': 1, 'radius': 244.68687473313042, 'idx_start': 4705}
# 3993: {'idx_end': 4710, 'is_leaf': 1, 'radius': 142.51228017262233, 'idx_start': 4708}
# 3994: {'idx_end': 4713, 'is_leaf': 1, 'radius': 173.01766126933717, 'idx_start': 4710}
# 3995: {'idx_end': 4715, 'is_leaf': 1, 'radius': 162.37918585828666, 'idx_start': 4713}
# 3996: {'idx_end': 4718, 'is_leaf': 1, 'radius': 223.00996489942875, 'idx_start': 4715}
# 3997: {'idx_end': 4720, 'is_leaf': 1, 'radius': 196.49173010587495, 'idx_start': 4718}
# 3998: {'idx_end': 4723, 'is_leaf': 1, 'radius': 221.46707806504037, 'idx_start': 4720}
# 3999: {'idx_end': 4725, 'is_leaf': 1, 'radius': 158.8718036657229, 'idx_start': 4723}
# 4000: {'idx_end': 4727, 'is_leaf': 1, 'radius': 149.60614960622442, 'idx_start': 4725}
# 4001: {'idx_end': 4729, 'is_leaf': 1, 'radius': 143.29776690514058, 'idx_start': 4727}
# 4002: {'idx_end': 4732, 'is_leaf': 1, 'radius': 233.9907405575415, 'idx_start': 4729}
# 4003: {'idx_end': 4734, 'is_leaf': 1, 'radius': 173.8454773642386, 'idx_start': 4732}
# 4004: {'idx_end': 4737, 'is_leaf': 1, 'radius': 213.19735249554842, 'idx_start': 4734}
# 4005: {'idx_end': 4739, 'is_leaf': 1, 'radius': 100.39920318408906, 'idx_start': 4737}
# 4006: {'idx_end': 4742, 'is_leaf': 1, 'radius': 209.78375109198103, 'idx_start': 4739}
# 4007: {'idx_end': 4744, 'is_leaf': 1, 'radius': 158.1850182539421, 'idx_start': 4742}
# 4008: {'idx_end': 4747, 'is_leaf': 1, 'radius': 268.9136581796386, 'idx_start': 4744}
# 4009: {'idx_end': 4749, 'is_leaf': 1, 'radius': 113.63098169073433, 'idx_start': 4747}
# 4010: {'idx_end': 4752, 'is_leaf': 1, 'radius': 215.39447016527095, 'idx_start': 4749}
# 4011: {'idx_end': 4754, 'is_leaf': 1, 'radius': 194.35084255027041, 'idx_start': 4752}
# 4012: {'idx_end': 4757, 'is_leaf': 1, 'radius': 256.22212585523874, 'idx_start': 4754}
# 4013: {'idx_end': 4759, 'is_leaf': 1, 'radius': 173.16682707724362, 'idx_start': 4757}
# 4014: {'idx_end': 4762, 'is_leaf': 1, 'radius': 229.03687233475944, 'idx_start': 4759}
# 4015: {'idx_end': 4764, 'is_leaf': 1, 'radius': 152.1528836401072, 'idx_start': 4762}
# 4016: {'idx_end': 4766, 'is_leaf': 1, 'radius': 152.5377002580018, 'idx_start': 4764}
# 4017: {'idx_end': 4768, 'is_leaf': 1, 'radius': 188.1515346735179, 'idx_start': 4766}
# 4018: {'idx_end': 4771, 'is_leaf': 1, 'radius': 196.96474585851936, 'idx_start': 4768}
# 4019: {'idx_end': 4773, 'is_leaf': 1, 'radius': 96.43650760992955, 'idx_start': 4771}
# 4020: {'idx_end': 4776, 'is_leaf': 1, 'radius': 221.13545371307808, 'idx_start': 4773}
# 4021: {'idx_end': 4778, 'is_leaf': 1, 'radius': 148.86487161180773, 'idx_start': 4776}
# 4022: {'idx_end': 4781, 'is_leaf': 1, 'radius': 172.0807304080784, 'idx_start': 4778}
# 4023: {'idx_end': 4783, 'is_leaf': 1, 'radius': 111.26207799605399, 'idx_start': 4781}
# 4024: {'idx_end': 4786, 'is_leaf': 1, 'radius': 195.5720952601481, 'idx_start': 4783}
# 4025: {'idx_end': 4788, 'is_leaf': 1, 'radius': 97.3883976662518, 'idx_start': 4786}
# 4026: {'idx_end': 4791, 'is_leaf': 1, 'radius': 225.54698943777655, 'idx_start': 4788}
# 4027: {'idx_end': 4793, 'is_leaf': 1, 'radius': 105.22713528363299, 'idx_start': 4791}
# 4028: {'idx_end': 4796, 'is_leaf': 1, 'radius': 177.3323934812187, 'idx_start': 4793}
# 4029: {'idx_end': 4798, 'is_leaf': 1, 'radius': 158.871016865884, 'idx_start': 4796}
# 4030: {'idx_end': 4801, 'is_leaf': 1, 'radius': 241.27554556748785, 'idx_start': 4798}
# 4031: {'idx_end': 4803, 'is_leaf': 1, 'radius': 65.06150935845248, 'idx_start': 4801}
# 4032: {'idx_end': 4805, 'is_leaf': 1, 'radius': 85.00441165021967, 'idx_start': 4803}
# 4033: {'idx_end': 4807, 'is_leaf': 1, 'radius': 178.24842215290434, 'idx_start': 4805}
# 4034: {'idx_end': 4810, 'is_leaf': 1, 'radius': 127.07784141138761, 'idx_start': 4807}
# 4035: {'idx_end': 4812, 'is_leaf': 1, 'radius': 138.1267533825363, 'idx_start': 4810}
# 4036: {'idx_end': 4815, 'is_leaf': 1, 'radius': 177.55187035530398, 'idx_start': 4812}
# 4037: {'idx_end': 4817, 'is_leaf': 1, 'radius': 121.31364309095659, 'idx_start': 4815}
# 4038: {'idx_end': 4820, 'is_leaf': 1, 'radius': 221.67869641543018, 'idx_start': 4817}
# 4039: {'idx_end': 4822, 'is_leaf': 1, 'radius': 86.87347120957007, 'idx_start': 4820}
# 4040: {'idx_end': 4824, 'is_leaf': 1, 'radius': 180.21792363691242, 'idx_start': 4822}
# 4041: {'idx_end': 4826, 'is_leaf': 1, 'radius': 77.45321168292507, 'idx_start': 4824}
# 4042: {'idx_end': 4829, 'is_leaf': 1, 'radius': 165.6659959744975, 'idx_start': 4826}
# 4043: {'idx_end': 4831, 'is_leaf': 1, 'radius': 149.09812205390114, 'idx_start': 4829}
# 4044: {'idx_end': 4834, 'is_leaf': 1, 'radius': 267.6324179002071, 'idx_start': 4831}
# 4045: {'idx_end': 4836, 'is_leaf': 1, 'radius': 131.5750736271882, 'idx_start': 4834}
# 4046: {'idx_end': 4839, 'is_leaf': 1, 'radius': 182.60309112632478, 'idx_start': 4836}
# 4047: {'idx_end': 4841, 'is_leaf': 1, 'radius': 112.58108189211897, 'idx_start': 4839}
# 4048: {'idx_end': 4843, 'is_leaf': 1, 'radius': 171.7803830476577, 'idx_start': 4841}
# 4049: {'idx_end': 4845, 'is_leaf': 1, 'radius': 128.5213989964317, 'idx_start': 4843}
# 4050: {'idx_end': 4848, 'is_leaf': 1, 'radius': 178.73195324594616, 'idx_start': 4845}
# 4051: {'idx_end': 4850, 'is_leaf': 1, 'radius': 121.45060724426206, 'idx_start': 4848}
# 4052: {'idx_end': 4853, 'is_leaf': 1, 'radius': 171.7850724338733, 'idx_start': 4850}
# 4053: {'idx_end': 4855, 'is_leaf': 1, 'radius': 143.91229968282767, 'idx_start': 4853}
# 4054: {'idx_end': 4858, 'is_leaf': 1, 'radius': 164.58196201960354, 'idx_start': 4855}
# 4055: {'idx_end': 4860, 'is_leaf': 1, 'radius': 72.57926701200557, 'idx_start': 4858}
# 4056: {'idx_end': 4863, 'is_leaf': 1, 'radius': 212.2789045885939, 'idx_start': 4860}
# 4057: {'idx_end': 4865, 'is_leaf': 1, 'radius': 164.05486887014357, 'idx_start': 4863}
# 4058: {'idx_end': 4868, 'is_leaf': 1, 'radius': 186.69910432445985, 'idx_start': 4865}
# 4059: {'idx_end': 4870, 'is_leaf': 1, 'radius': 201.5508620671219, 'idx_start': 4868}
# 4060: {'idx_end': 4873, 'is_leaf': 1, 'radius': 224.43583591851916, 'idx_start': 4870}
# 4061: {'idx_end': 4875, 'is_leaf': 1, 'radius': 111.42822802144886, 'idx_start': 4873}
# 4062: {'idx_end': 4878, 'is_leaf': 1, 'radius': 227.2272479748462, 'idx_start': 4875}
# 4063: {'idx_end': 4880, 'is_leaf': 1, 'radius': 179.6413092804659, 'idx_start': 4878}
# 4064: {'idx_end': 4882, 'is_leaf': 1, 'radius': 181.77183500201565, 'idx_start': 4880}
# 4065: {'idx_end': 4884, 'is_leaf': 1, 'radius': 113.7123564086155, 'idx_start': 4882}
# 4066: {'idx_end': 4887, 'is_leaf': 1, 'radius': 254.80275595928015, 'idx_start': 4884}
# 4067: {'idx_end': 4889, 'is_leaf': 1, 'radius': 96.01562372864116, 'idx_start': 4887}
# 4068: {'idx_end': 4892, 'is_leaf': 1, 'radius': 121.20918557051142, 'idx_start': 4889}
# 4069: {'idx_end': 4894, 'is_leaf': 1, 'radius': 50.05496978322932, 'idx_start': 4892}
# 4070: {'idx_end': 4897, 'is_leaf': 1, 'radius': 100.07774755436672, 'idx_start': 4894}
# 4071: {'idx_end': 4899, 'is_leaf': 1, 'radius': 85.3243810408256, 'idx_start': 4897}
# 4072: {'idx_end': 4902, 'is_leaf': 1, 'radius': 168.85595439111208, 'idx_start': 4899}
# 4073: {'idx_end': 4904, 'is_leaf': 1, 'radius': 105.0844898165281, 'idx_start': 4902}
# 4074: {'idx_end': 4907, 'is_leaf': 1, 'radius': 127.0078737716682, 'idx_start': 4904}
# 4075: {'idx_end': 4909, 'is_leaf': 1, 'radius': 169.03402024444665, 'idx_start': 4907}
# 4076: {'idx_end': 4912, 'is_leaf': 1, 'radius': 262.796076412449, 'idx_start': 4909}
# 4077: {'idx_end': 4914, 'is_leaf': 1, 'radius': 146.1651463242862, 'idx_start': 4912}
# 4078: {'idx_end': 4917, 'is_leaf': 1, 'radius': 207.71962941533585, 'idx_start': 4914}
# 4079: {'idx_end': 4919, 'is_leaf': 1, 'radius': 78.08008709011537, 'idx_start': 4917}
# 4080: {'idx_end': 4921, 'is_leaf': 1, 'radius': 217.07372019661892, 'idx_start': 4919}
# 4081: {'idx_end': 4923, 'is_leaf': 1, 'radius': 121.47324808368302, 'idx_start': 4921}
# 4082: {'idx_end': 4926, 'is_leaf': 1, 'radius': 209.00159489024642, 'idx_start': 4923}
# 4083: {'idx_end': 4928, 'is_leaf': 1, 'radius': 168.51557791492155, 'idx_start': 4926}
# 4084: {'idx_end': 4931, 'is_leaf': 1, 'radius': 161.73778504453156, 'idx_start': 4928}
# 4085: {'idx_end': 4933, 'is_leaf': 1, 'radius': 227.8815481779953, 'idx_start': 4931}
# 4086: {'idx_end': 4936, 'is_leaf': 1, 'radius': 178.74034550462048, 'idx_start': 4933}
# 4087: {'idx_end': 4938, 'is_leaf': 1, 'radius': 150.9147110125451, 'idx_start': 4936}
# 4088: {'idx_end': 4941, 'is_leaf': 1, 'radius': 264.72585400330235, 'idx_start': 4938}
# 4089: {'idx_end': 4943, 'is_leaf': 1, 'radius': 127.76736672562365, 'idx_start': 4941}
# 4090: {'idx_end': 4946, 'is_leaf': 1, 'radius': 202.64775131027514, 'idx_start': 4943}
# 4091: {'idx_end': 4948, 'is_leaf': 1, 'radius': 152.13563027772292, 'idx_start': 4946}
# 4092: {'idx_end': 4951, 'is_leaf': 1, 'radius': 169.62278410900134, 'idx_start': 4948}
# 4093: {'idx_end': 4953, 'is_leaf': 1, 'radius': 112.88932633336067, 'idx_start': 4951}
# 4094: {'idx_end': 4956, 'is_leaf': 1, 'radius': 204.64929350802402, 'idx_start': 4953}

# %%
# Get matches in usual format
def matchFromIndex(i,j) :
    return (features.getPosition(ks[i]), features.getPosition(ks[j]))

# %%
idxt = numpy.array(bt.idx_array[1:10])
idxt
# Out:
# array([4914,  838, 3023, 1384, 2065, 1325,  595, 1487, 1516])

# %%
# utility function for getting a node
def getNode(bt, index) :
    return bt.node_data[index]

# %%
# Id like to show all keypoints from some node. Let's try
def showNode(index) :
    node = getNode(bt, index)
    idx = numpy.array(bt.idx_array[node['idx_start']:node['idx_end']])
    keypoints = ks[idx]
    im_idx = indices[idx]
    positions = numpy.array(features.getPositions(keypoints))
    display.compareKeypoints(images[0], images[1], positions[im_idx == 0], positions[im_idx == 1])

index = 564
print(getNode(bt, index))
showNode(index)
# Out:
# {'idx_end': 521, 'is_leaf': 0, 'radius': 372.2211036467438, 'idx_start': 511}

# %%
# I'd like to go through the tree and find all 
# the nodes first nodes (counting from the top) 
# that have a radius less than a certain size
def filterNodes(bt, radius) :
    # Initialize an empty set of nodes
    akin = []
    
    # Initialize a list of nodes to skip
    skip = numpy.zeros(bt.node_data.shape, dtype=numpy.bool)
    
    # For each node, add it to akin if the node is small enough and shouldn't be skipped
    for i,n in enumerate(bt.node_data) :
        if n['radius'] < radius and not skip[i] :
            
            # Update skip list so children aren't expanded
            # If parent is in pos 'i', then the two children of the binary tree are at pos '2*i + 1' and '2*i+2'
            j = 2*i+1
            k = 2
            while j < bt.node_data.shape[0] :
                #print("skipping %i:%i" % (j, j-1+k))
                skip[j : j + k] = True
                k = k*2
                j = 2*j+1
            
            # Add node to akin
            akin.append(i)
    
    # Return akin
    return akin
n = filterNodes(bt, 300)

getNode(bt,n[0])
# Out:
# {'idx_end': 3484, 'idx_start': 3445, 'is_leaf': 0, 'radius': 266.7081131499131}

# %%
# Produce new ball tree with node as head. 
# This could be done more efficiently, but 
# that would be tricky because of the 
# underlying data structure of the ball tree
def newTree(bt, index) :
    node = getNode(bt, index)
    idx = numpy.array(bt.idx_array[node['idx_start']: node['idx_end']+1])
    node_features = ds[idx]
    node_bt = BallTree(node_features, leaf_size=5)
    return (node_bt, idx)

showNode(n[5])

# %%
# Now find all matches
def NN(descriptor, node_tree) :
    (dist, index) = node_tree.query(descriptor, k=3)
    return index[0][1], dist[0][1], dist[0][1]/float(dist[0][2])

def keepMatch(m, n, s, u, nn, idx, dist_threshold = 100, ratio_threshold = 0.95) :
    keep = (s < dist_threshold
        and u < ratio_threshold
        and indices[idx[m]] < indices[idx[n]])
        #and m == nn[n])
    return keep

def getPos(m,n, idx) :
    if indices[idx[m]] < indices[idx[n]] :
        return features.getPositions([ks[idx[m]], ks[idx[n]]])
    else :
        return features.getPositions([ks[idx[n]], ks[idx[m]]])

def getMatches(bt, node_indices) :

    for node_index in node_indices :

        # Construct node tree
        node_tree, idx = newTree(bt, node_index)
        
        # Get nearest neighbors
        nn, ss, uu = zip(*[NN(d, node_tree) for d in ds[idx]])
        #matches = [NN(d) for d in ds]
        
        # Yield match
        for m,n in enumerate(nn) :
            if keepMatch(m, n, ss[m], uu[m], nn, idx) :
                yield (numpy.array(getPos(m, n, idx)), ss[m], uu[m])

# %%
match_pos, match_dist, match_ratio = zip(*list(getMatches(bt, [n[9]])))

# display matches
display.matchPoints(images[0], images[1], match_pos)
print(len(match_pos))
# Out:
# 1

# %%
import itertools

# %timeit match_pos, match_dist, match_ratio = zip(*list(getMatches(bt, n)))
display.matchPoints(images[0], images[1], match_pos)
print(len(match_pos))
# Out:
# 1 loops, best of 3: 599 ms per loop
# 184

# %%
import ratiomatch

threshold_ratio = 0.25
options = {"use_ball_tree":True}
# %timeit match_pos_r, scores_r, unique_r = ratiomatch.match(paths, options)(threshold_ratio)
display.matchPoints(images[0], images[1], match_pos_r)
print(len(match_pos_r))
# Out:
# 1 loops, best of 3: 1.73 s per loop
# 252

# %%
import ballmatch

threshold_ratio = 0.5
options = {
           "leaf_size": 2,
           "radius_size": 300,
           "dist_threshold": 125
           }
# %timeit match_pos_b, scores_b, unique_b = ballmatch.match(paths, options)(threshold_ratio)
display.matchPoints(images[0], images[1], match_pos_b)
print(len(match_pos_b))
# Out:
# 1 loops, best of 3: 1.25 s per loop
# 191
