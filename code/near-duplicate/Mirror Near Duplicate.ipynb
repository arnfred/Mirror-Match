# %%
#Stupid hack to load files from sibling dir
import sys; import os
sys.path.insert(0, os.path.abspath('..'))

# %load_ext autoreload
# %autoreload 2

# %%
import display
import matching
from sklearn.neighbors.ball_tree import BallTree
import ballmatch
import features
import numpy
import louvain
import mirrormatch
import scipy
import sklearn
import scoring
from itertools import combinations
import os
import duplicates

# %%
folder = '../../images/near-duplicate samples/'
files, paths = duplicates.get_files(folder, verbose = True)
# Out:
#  0: 604.jpg
#  1: 312.jpg
#  2: 668.jpg
#  3: 648.jpg
#  4: 689.jpg
#  5: 311.jpg
#  6: 572.jpg
#  7: 584.jpg
#  8: 688.jpg
#  9: 314.jpg
# 10: 313.jpg
# 11: 568.jpg
# 12: 067.jpg
# 13: 656.jpg
# 14: 647.jpg
# 15: 588.jpg
# 16: 593.jpg
# 17: 686.jpg
# 18: 658.jpg
# 19: 310.jpg

# %%
options = {
       "verbose" : True,
       "kp_threshold" : (0.05, 0.3),
       "neighbors" : 5,
       "tree_type" : "flann",
}
options.update({"feature_type" : "L"})
matches_L = duplicates.get_matches(paths, options)
options.update({"feature_type" : "u"})
matches_u = duplicates.get_matches(paths, options)
options.update({"feature_type" : "v"})
matches_v = duplicates.get_matches(paths, options)

# %%
scores, counts, labels = duplicates.get_scores(matches_L + matches_u + matches_v, files, threshold = 0.8)
numpy.savez("califoniaND-sample-color", scores = scores, counts = counts, labels = labels)

# %%
data = numpy.load("califoniaND-sample-color.npz")
scores = data['scores']
counts = data['counts']
labels = data['labels']
duplicates.print_scores(scores, labels)
duplicates.heatmap(scores, labels, cmap=cm.jet)
# Out:
#        067  310  311  312  313  314  568  572  584  588  593  604  647  648  656  658  668  686  688  689
#     +-----------------------------------------------------------------------------------------------------
# 067 |    3   30   20   23   21   27   32   28   22   28   23   28   18   17  157  242  131   35   24   28
# 310 |   30    2   59  453   67   80   33   39   36   24   24   37   26   25   30   33   42   39   34   36
# 311 |   20   59    1   96   67  106   31   25   20   22   19   23   22   26   25   22   31   25   25   23
# 312 |   23  453   96    2   86  271   25   25   26   26   23   26   23   15   20   30   27   29   28   23
# 313 |   21   67   67   86    2   88   26   24   30   28   17   24   21   18   25   25   24   29   27   34
# 314 |   27   80  106  271   88    0   26   32   21   26   22   23   23   24   20   20   27   27   31   34
# 568 |   32   33   31   25   26   26    2 10199  341  413  320  229   21   24   30   27   34   32   33   30
# ...

# %%
scores_norm_count = duplicates.norm_counts(scores, modifier = 1000)
#duplicates.print_scores(scores_norm_count, labels)#, use_float=True)
duplicates.heatmap(scores_norm_count, labels, cmap=cm.jet)

# %%
scores_capped = duplicates.cap(scores_norm_count) * 100
#duplicates.print_scores(scores_capped, labels) #,use_float=True)
duplicates.heatmap(scores_capped, labels, cmap=cm.jet)

# %%
scores_trimmed = duplicates.trim(scores_capped, margins = (0.3, 0.7), verbose = True)
duplicates.heatmap(scores_trimmed, labels, cmap=cm.jet)
# Out:
# Cut: (28.59, 66.72)

# %%
for i in range(scores_norm.shape[0]) :
    scores_trimmed[i,i] = 1
scores_squared = (scores_trimmed).dot(scores_trimmed)
duplicates.heatmap(scores_squared, labels, cmap=cm.jet)

# %%
scores_squared_norm = duplicates.norm_scores(scores_squared)
#scores_squared_trimmed = duplicates.trim(scores_squared_norm, (0.5, 0.9))
duplicates.heatmap(scores_squared_norm, labels, cmap = cm.jet)

# %%
# Try to cluster with Louvain
#p = louvain.cluster(scores_squared, verbose = True)
#print_clusters(p, labels)

# %%
#from sklearn.cluster import AffinityPropagation
#p_af = AffinityPropagation(affinity = 'precomputed').fit(scores_squared).labels_
#print_clusters(p_af, files)

# %%
#from sklearn.cluster import spectral_clustering
#p_sp = spectral_clustering(scores_squared, n_clusters=5, assign_labels='kmeans')
#print_clusters(p_sp, files)
