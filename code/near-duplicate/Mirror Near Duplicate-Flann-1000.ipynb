# %%
#Stupid hack to load files from sibling dir
import sys; import os
sys.path.insert(0, os.path.abspath('..'))

# %load_ext autoreload
# %autoreload 2

# %%
import display
import matching
from sklearn.neighbors.ball_tree import BallTree
import ballmatch
import features
import numpy
import louvain
import mirrormatch
import scipy
import sklearn
import scoring
from itertools import combinations
import os

# %%
folder = '../near-duplicate/resources/california3/'
files = [path for path in os.listdir(folder) if path[-3:] in ["jpg", "png"]]
paths = [folder + p for p in files]
for i,f in enumerate(files) :
    print("%2i: %s" % (i,f))
# Out:
#  0: 443.jpg
#  1: 641.jpg
#  2: 136.jpg
#  3: 203.jpg
#  4: 075.jpg
#  5: 133.jpg
#  6: 068.jpg
#  7: 157.jpg
#  8: 595.jpg
#  9: 034.jpg
# 10: 349.jpg
# 11: 145.jpg
# 12: 106.jpg
# 13: 296.jpg
# 14: 604.jpg
# 15: 556.jpg
# 16: 642.jpg
# 17: 289.jpg
# 18: 054.jpg
# 19: 622.jpg
# 20: 165.jpg
# 21: 529.jpg
# 22: 172.jpg
# 23: 134.jpg
# 24: 049.jpg
# 25: 685.jpg
# 26: 206.jpg
# 27: 148.jpg
# 28: 256.jpg
# 29: 664.jpg
# 30: 268.jpg
# 31: 678.jpg
# 32: 230.jpg
# 33: 592.jpg
# 34: 402.jpg
# 35: 508.jpg
# 36: 546.jpg
# 37: 654.jpg
# 38: 694.jpg
# 39: 122.jpg
# 40: 323.jpg
# 41: 351.jpg
# 42: 258.jpg
# 43: 063.jpg
# 44: 535.jpg
# 45: 646.jpg
# 46: 061.jpg
# 47: 056.jpg
# 48: 550.jpg
# 49: 312.jpg
# 50: 315.jpg
# 51: 497.jpg
# 52: 237.jpg
# 53: 126.jpg
# 54: 120.jpg
# 55: 459.jpg
# 56: 341.jpg
# 57: 170.jpg
# 58: 209.jpg
# 59: 036.jpg
# 60: 668.jpg
# 61: 683.jpg
# 62: 007.jpg
# 63: 090.jpg
# 64: 648.jpg
# 65: 596.jpg
# 66: 445.jpg
# 67: 633.jpg
# 68: 436.jpg
# 69: 149.jpg
# 70: 333.jpg
# 71: 644.jpg
# 72: 538.jpg
# 73: 345.jpg
# 74: 299.jpg
# 75: 360.jpg
# 76: 458.jpg
# 77: 330.jpg
# 78: 123.jpg
# 79: 243.jpg
# 80: 267.jpg
# 81: 673.jpg
# 82: 066.jpg
# 83: 109.jpg
# 84: 407.jpg
# 85: 298.jpg
# 86: 689.jpg
# 87: 576.jpg
# 88: 041.jpg
# 89: 164.jpg
# 90: 659.jpg
# 91: 506.jpg
# 92: 118.jpg
# 93: 020.jpg
# 94: 279.jpg
# 95: 045.jpg
# 96: 677.jpg
# 97: 514.jpg
# 98: 681.jpg
# 99: 541.jpg
# 100: 624.jpg
# 101: 620.jpg
# 102: 571.jpg
# 103: 657.jpg
# 104: 553.jpg
# 105: 152.jpg
# 106: 499.jpg
# 107: 587.jpg
# 108: 253.jpg
# 109: 552.jpg
# 110: 156.jpg
# 652: 635.jpg
# 653: 355.jpg
# 654: 154.jpg
# 655: 155.jpg
# 656: 485.jpg
# 657: 228.jpg
# 658: 048.jpg
# 659: 009.jpg
# 660: 623.jpg
# 661: 610.jpg
# 662: 194.jpg
# 663: 410.jpg
# 664: 292.jpg
# 665: 565.jpg
# 666: 178.jpg
# 667: 383.jpg
# 668: 559.jpg
# 669: 558.jpg
# 670: 670.jpg
# 671: 551.jpg
# 672: 660.jpg
# 673: 582.jpg
# 674: 428.jpg
# 675: 269.jpg
# 676: 627.jpg
# 677: 421.jpg
# 678: 008.jpg
# 679: 487.jpg
# 680: 320.jpg
# 681: 416.jpg
# 682: 112.jpg
# 683: 024.jpg
# 684: 335.jpg
# 685: 462.jpg
# 686: 640.jpg
# 687: 424.jpg
# 688: 431.jpg
# 689: 386.jpg
# 690: 639.jpg
# 691: 679.jpg
# 692: 043.jpg
# 693: 534.jpg
# 694: 113.jpg
# 695: 095.jpg
# 696: 408.jpg
# 697: 675.jpg
# 698: 119.jpg
# 699: 453.jpg
# 700: 616.jpg

# %%
dt = 5
max_kp = 50
keypoint_type = "SIFT"
descriptor_type = "SIFT"
nb_thresholds = 50
thresholds = numpy.linspace(0.3,0.8, nb_thresholds)

# %%
options = {
       "verbose" : True,
       "kp_threshold" : (0.05, 0.3),
       "neighbors" : 10,
       "tree_type" : "flann",
}
mm_fun  = mirrormatch.match(paths, options)
# Out:
# :
# :
# :
# :
# :
# :
# :
# :
# :
# :

# %%
matches = mm_fun(0.99)
numpy.savez("califoniaND-%ikp" % max_kp, matches = matches)

# %%
data = numpy.load("califoniaND-%ikp.npz" % max_kp)
matches = data['matches']

# %%
def print_scores(scores, files) : 
    
    # Get labels
    labels = [f[:3] for f in files]
    rows = sorted(enumerate(labels), key=lambda e : e[1])
    
    # Top row
    print("      "),
    for i,f in rows :
        print("%s " % f),
    print("\n    +%s-" % ("-----" * scores.shape[1]))
    
    
    # Fields
    for i,f in rows :
        print("%s |" % f),
        for j,_ in rows :
            print("%4.0f" % scores[i,j]),
        print("")

# %%
def print_clusters(p, files) :
    labels = [f[:3] for f in files]
    for i,k in enumerate(set(p)) :
        members = [labels[j] for j in numpy.array(range(len(p)))[p == k]]
        print("Cluster %i:  %s" % (i+1, ", ".join(members)))

# %%
calif_ground_truth = numpy.load("../near-duplicate/resources/california3_non_binary10_groundtruth.npy")
for i in range(calif_ground_truth.shape[0]) :
    calif_ground_truth[i,i] = 0
labels = [f[:3] for f in files]
def duplicates_finder(ground_truth, files) :
    """Given a label, we want to return all the other labels judged as duplicates"""
    
    labels = sorted([f[:3] for f in files])
    indexMap = dict([(l,i) for i,l in enumerate(labels)])
    
    def dup_fun(label) :
        # First find the correct index for label
        index = indexMap[label]
        
        # Now get the row of ground_truth corresponding to this label
        row = ground_truth[index]
        
        # For each non-zero index, find the label it corresponds to
        dup = [(labels[i], nz) for i,nz in enumerate(row) if nz > 0]
    
        return dup
    
    return dup_fun

duplicates = duplicates_finder(calif_ground_truth, files)

# %%
def normalize_scores(scores, score_bar = 10, cut_norm = (0.3, 0.7), order = 0.01, max_dist = 20, diagonal = 1.0) :
    
    scores_norm = numpy.zeros(scores.shape)
    statistic = -1*ceil(scores.shape[0]*2*order) - 1
    
    # normalize according to row and col
    for i in range(scores.shape[0]) :
        for j in range(scores.shape[1]) :
            if abs(i - j) > max_dist :
                scores_norm[i,j] = 0
            elif i == j :
                scores_norm[i,j] = diagonal
            elif scores[i,j] < score_bar :
                scores_norm[i,j] = 0
            else :
                # Get all values from cols and rows
                n1, n2 = (scores[i], scores.T[j])
                n1[i] = 0
                n2[j] = 0
                neighbors = numpy.sort(numpy.concatenate((n1,n2)))
                #neighbors = numpy.sort(numpy.concatenate((scores[i], scores.T[j])))
                #N[i,j] = neighbors[-1*order]
                
                # Calculate normalized value according to cut
                s = scores[i,j] / neighbors[statistic]
                s_norm = (s - cut_norm[0]) / (cut_norm[1] - cut_norm[0])
                if s_norm <= 0 :
                    scores_norm[i,j] = 0
                elif s_norm >= 1 :
                    scores_norm[i,j] = 1
                else :
                    scores_norm[i,j] = s_norm
                    
    return scores_norm

# %%
def sort_scores(scores, files) :
    # Get labels
    fname = [f[:3] for f in files]
    rows = sorted(enumerate(fname), key=lambda e : e[1])
    indices, labels = zip(*rows)
    idx = numpy.array(indices)
    
    return scores[idx][:,idx], labels

# %%
def heatmap(scores, labels = None, size = (12,12)) :
    
    fig, ax = plt.subplots(figsize=size)
    
    # For colormap: http://wiki.scipy.org/Cookbook/Matplotlib/Show_colormaps
    #heatmap = ax.pcolor(scores_sorted, cmap=cm.Blues)
    heatmap = ax.pcolor(scores, cmap=cm.jet)

    # put the major ticks at the middle of each cell
    if labels != None and scores.shape[0] < size[0]*3 : 
        ax.set_xticks(numpy.arange(scores.shape[0])+0.5, minor=False)
        ax.set_yticks(numpy.arange(scores.shape[1])+0.5, minor=False)
        ax.set_xticklabels(labels, minor=False)
        ax.set_yticklabels(labels, minor=False)

    xlim(0,scores.shape[0])
    ylim(scores.shape[0],0)

# %%
nb_images = len(paths)
scores = numpy.zeros((nb_images, nb_images))
for p,s,u,(i,j) in zip(*matches) :
    scores[i,j] = scores[i,j] + (1/u) - 1
    scores[j,i] = scores[j,i] + (1/u) - 1

# %%
n_start = 0
n_end = len(scores)
scores_sorted, labels = sort_scores(scores, files)
scores_p, labels_p = scores_sorted[n_start:n_end][:,n_start:n_end], labels[n_start:n_end]
ground_truth_p = calif_ground_truth[n_start:n_end][:,n_start:n_end]

# %%
numpy.sum(scores_p) / (scores_p.shape[0]**2)
# Out:
# 0.14925895605804307

# %%
scores_norm = normalize_scores(scores_sorted, score_bar = 2, cut_norm = (0.0, 1.0), order = 0.05, max_dist = 999)
heatmap(scores_norm, labels, size=(12,12))
# Out:
# -c:25: RuntimeWarning: divide by zero encountered in double_scalars

# %%
scores_squared = normalize_scores(scores_norm.dot(scores_norm), score_bar = 1, cut_norm = (0.3, 0.7), order = 0, max_dist = 55, diagonal = 0)
heatmap(scores_squared, labels, size=(12,12))

# %%
heatmap(calif_ground_truth, labels)

# %%
l = numpy.array([[1,3],[5,2]])
m = numpy.array([[2,2],[2,2]])
numpy.min((l,m), axis=0)
# Out:
# array([[1, 2],
#        [2, 2]])

# %%
scores_norm = normalize_scores(scores_sorted, score_bar = 2, cut_norm = (0.0, 1.0), order = 0.05, max_dist = 999)
scores_squared = normalize_scores(scores_norm.dot(scores_norm), score_bar = 1, cut_norm = (0.3, 0.7), order = 0.0, max_dist = 555, diagonal = 0)

# %%
result = scores_squared
sTP = numpy.sum(numpy.min((calif_ground_truth, result), axis = 0))
sTN = numpy.sum(numpy.min((1 - calif_ground_truth, 1- result), axis = 0))
sFP = numpy.sum(numpy.max((result - calif_ground_truth,  numpy.zeros(result.shape)), axis = 0))
sFN = numpy.sum(numpy.max((calif_ground_truth - result,  numpy.zeros(result.shape)), axis = 0))
sPrecision = sTP / (sTP + sFP)
sRecall = sTP / (sTP + sFN)
sF1 = 2 * sPrecision * sRecall / (sPrecision + sRecall)
print("Precision: %.4f" % sPrecision)
print("Recall: %.4f" % sRecall)
print("F1: %.4f" % sF1)
# Out:
# Precision: 0.7883
# Recall: 0.3531
# F1: 0.4877

# %%
# Try to cluster with Louvain
p = louvain.cluster(scores, verbose = True)
print_clusters(p, files)
# Out:
# Moved 516 vertices (modularity now: 0.615319, change of 0.615319 (0.624188))
# Moved 124 vertices (modularity now: 0.666283, change of 0.050964 (0.051550))
# Moved 96 vertices (modularity now: 0.676110, change of 0.009827 (0.010172))
# Moved 90 vertices (modularity now: 0.688799, change of 0.012689 (0.013840))
# Moved 38 vertices (modularity now: 0.699082, change of 0.010284 (0.011376))
# Moved 3 vertices (modularity now: 0.700117, change of 0.001034 (0.001138))
# Moved 0 vertices (modularity now: 0.700117, change of 0.000000 (0.000000))
# Cluster 1:  556, 555
# Cluster 2:  253, 251, 254, 252
# Cluster 3:  576, 575, 577, 573, 574
# Cluster 4:  075, 133, 068, 034, 289, 054, 165, 134, 049, 685, 256, 664, 268, 402, 546, 654, 323, 258, 063, 535, 056, 312, 315, 120, 036, 668, 007, 090, 299, 360, 330, 123, 243, 267, 673, 066, 407, 298, 689, 041, 164, 659, 020, 045, 541, 657, 553, 552, 306, 526, 607, 286, 264, 548, 019, 096, 086, 166, 523, 288, 193, 010, 672, 309, 311, 110, 395, 561, 317, 197, 143, 305, 241, 290, 192, 275, 271, 671, 091, 046, 087, 050, 543, 196, 412, 324, 260, 293, 127, 089, 405, 321, 411, 418, 051, 026, 562, 326, 018, 557, 690, 358, 481, 297, 439, 071, 064, 079, 441, 542, 030, 391, 263, 005, 266, 413, 031, 015, 415, 419, 314, 082, 427, 044, 287, 609, 135, 313, 047, 180, 255, 653, 242, 003, 080, 665, 302, 291, 141, 012, 013, 643, 067, 038, 285, 652, 001, 628, 014, 273, 414, 328, 482, 316, 656, 006, 554, 111, 011, 392, 440, 329, 272, 004, 257, 124, 318, 608, 308, 088, 270, 042, 039, 032, 033, 265, 029, 035, 359, 040, 259, 081, 016, 655, 307, 262, 304, 325, 239, 052, 274, 303, 083, 547, 037, 294, 669, 283, 403, 322, 560, 663, 373, 301, 060, 444, 025, 327, 261, 319, 284, 658, 017, 142, 002, 057, 055, 533, 300, 404, 240, 417, 666, 674, 053, 310, 486, 065, 048, 009, 410, 292, 559, 558, 670, 551, 660, 269, 627, 008, 320, 416, 112, 640, 639, 043, 534, 113
# Cluster 5:  641, 642
# Cluster 6:  525, 524
# Cluster 7:  605, 606
# Cluster 8:  104, 103, 102
# Cluster 9:  077, 076, 078
# Cluster 10:  351, 352, 357, 350
# Cluster 11:  368, 371, 370, 369
# Cluster 12:  614, 611, 613, 615, 612, 610
# Cluster 13:  479, 480
# Cluster 14:  445, 449, 447, 448, 446, 450, 451
# Cluster 15:  459, 458, 457, 460, 461
# Cluster 16:  169, 167, 168
# Cluster 17:  688, 686, 687
# Cluster 18:  182, 183, 181
# Cluster 19:  100, 099, 101
# Cluster 20:  245, 244
# Cluster 21:  596, 599, 598, 597
# Cluster 22:  474, 473, 476, 475, 472, 477, 478
# Cluster 23:  276, 277
# Cluster 24:  349, 341, 342, 343, 348, 347
# Cluster 25:  296, 295
# Cluster 26:  436, 438, 437
# Cluster 27:  022, 021
# Cluster 28:  160, 162, 163, 161, 155
# Cluster 29:  246, 250, 247, 248, 249
# Cluster 30:  381, 382, 383
# Cluster 31:  109, 108, 107
# Cluster 32:  694, 693, 692
# Cluster 33:  129, 128, 130
# Cluster 34:  115, 114
# Cluster 35:  622, 620, 621, 619
# Cluster 36:  132, 131
# Cluster 37:  059, 058
# Cluster 38:  538, 536, 537
# Cluster 39:  580, 579, 581, 578, 582
# Cluster 40:  455, 456
# Cluster 41:  532, 531
# Cluster 42:  529, 530
# Cluster 43:  400, 401
# Cluster 44:  630, 629, 635
# Cluster 45:  226, 227, 228
# Cluster 46:  624, 623
# Cluster 47:  195, 194
# Cluster 48:  567, 563, 564, 566, 565
# Cluster 49:  174, 177, 179, 176, 175, 178
# Cluster 50:  429, 428
# Cluster 51:  422, 420, 421
# Cluster 52:  489, 488, 490, 487
# Cluster 53:  023, 024
# Cluster 54:  337, 336, 335
# Cluster 55:  463, 462
# Cluster 56:  425, 423, 426, 424
# Cluster 57:  432, 430, 431
# Cluster 58:  387, 386
# Cluster 59:  678, 680, 679
# Cluster 60:  644, 645
# Cluster 61:  677, 676, 675
# Cluster 62:  118, 116, 117, 119
# Cluster 63:  454, 452, 453
# Cluster 64:  571, 572, 569, 570, 568
# Cluster 65:  583, 584
# Cluster 66:  230, 231, 229, 234
# Cluster 67:  514, 513
# Cluster 68:  497, 498
# Cluster 69:  222, 221
# Cluster 70:  434, 433, 435
# Cluster 71:  279, 280, 281, 282, 278
# Cluster 72:  152, 153
# Cluster 73:  691, 695, 696
# Cluster 74:  172, 173
# Cluster 75:  683, 681, 682, 684
# Cluster 76:  465, 464, 466
# Cluster 77:  206, 207
# Cluster 78:  098, 097
# Cluster 79:  140, 138, 139
# Cluster 80:  356, 354, 353, 355
# Cluster 81:  338, 339, 340
# Cluster 82:  409, 406, 408
# Cluster 83:  364, 363, 361, 362
# Cluster 84:  633, 631, 634, 632
# Cluster 85:  093, 092, 094, 095
# Cluster 86:  189, 191, 187, 188, 190
# Cluster 87:  145, 144
# Cluster 88:  470, 467, 471, 469, 468
# Cluster 89:  394, 393
# Cluster 90:  198, 199
# Cluster 91:  235, 236
# Cluster 92:  545, 544
# Cluster 93:  374, 375, 376, 372
# Cluster 94:  662, 661, 667
# Cluster 95:  522, 521
# Cluster 96:  512, 510, 511, 509
# Cluster 97:  516, 515
# Cluster 98:  070, 069
# Cluster 99:  377, 379, 378, 380
# Cluster 100:  148, 149, 150, 151
# Cluster 101:  539, 540
# Cluster 102:  027, 028
# Cluster 103:  397, 396, 398, 399
# Cluster 104:  333, 332, 334, 331
# Cluster 105:  367, 366, 365
# Cluster 106:  216, 214, 217, 218, 215
# Cluster 107:  170, 171
# Cluster 108:  625, 626
# Cluster 109:  506, 505
# Cluster 110:  106, 105
# Cluster 111:  345, 346, 344
# Cluster 112:  443, 442
# Cluster 113:  604, 602, 601, 600, 603
# Cluster 114:  508, 507
# Cluster 115:  157, 156, 159, 158, 154
# Cluster 116:  550, 549
# Cluster 117:  519, 518, 520, 517
# Cluster 118:  126, 125
# Cluster 119:  492, 494, 496, 491, 493, 495
# Cluster 120:  636, 638, 637
# Cluster 121:  499, 503, 504, 502, 500, 501
# Cluster 122:  237, 238
# Cluster 123:  085, 084
# Cluster 124:  061, 062
# Cluster 125:  220, 219
# Cluster 126:  232, 233
# Cluster 127:  617, 618, 616
# Cluster 128:  528, 527
# Cluster 129:  203, 204, 205, 202, 201, 200
# Cluster 130:  700, 697, 701, 698, 699
# Cluster 131:  223, 225, 224
# Cluster 132:  186, 185, 184
# Cluster 133:  646, 648, 647
# Cluster 134:  649, 650, 651
# Cluster 135:  136, 137
# Cluster 136:  587, 589, 586, 588, 585
# Cluster 137:  483, 484, 485
# Cluster 138:  147, 146
# Cluster 139:  122, 121
# Cluster 140:  072, 074, 073
# Cluster 141:  595, 592, 591, 593, 590, 594
# Cluster 142:  384, 385
# Cluster 143:  209, 211, 208, 212, 210, 213
# Cluster 144:  389, 390, 388

# %%
duplicates("387")
# Out:
# [('386', 1.0),
#  ('388', 0.90000000000000002),
#  ('389', 0.90000000000000002),
#  ('390', 0.90000000000000002)]

# %%
#from sklearn.cluster import AffinityPropagation
#p_af = AffinityPropagation(affinity = 'precomputed').fit(scores).labels_
#print_clusters(p_af, files)

# %%
#from sklearn.cluster import spectral_clustering
#p_sp = spectral_clustering(scores, n_clusters=100, assign_labels='kmeans')
#print_clusters(p_sp, files)
