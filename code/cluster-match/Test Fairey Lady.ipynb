# %%
#Stupid hack to load files from sibling dir
import sys; import os
sys.path.insert(0, os.path.abspath('..'))

# %load_ext autoreload
# %autoreload 2

# %%
import fnmatch
import os
import matching
import weightMatrix
import display
import itertools

# %%
dt = 5
nb_tresholds = 50
tresholds_cluster = numpy.linspace(0.83,0.98, nb_tresholds)
tresholds_nocluster = numpy.linspace(0.3,0.8, nb_tresholds)
#tresholds_cluster = numpy.linspace(0.92,1.0, 1)
#tresholds_nocluster = numpy.linspace(0.6,0.8, 1)
directory = "Fairey Lady"
keypoint = "SIFT"
descriptor = "SIFT"
verbose = True

# %%
correct_us, total_us = matching.folderMatch(directory, dt, matching.uniqueMatch, tresholds_nocluster, keypoint, descriptor)

# %%
correct_ms, total_ms = matching.folderMatch(directory, dt, matching.mirrorMatch, tresholds_nocluster, keypoint, descriptor)

# %%
correct_cs, total_cs = matching.folderMatch(directory, dt, matching.clusterMatch, tresholds_cluster, keypoint, descriptor)

# %%
display.accuDetail([correct_us, correct_ms, correct_cs], [total_us, total_ms, total_cs], ["Unique Match", "Mirror Match", "Cluster Match"], treshold = 50)
# Out:
# [17, 23, 26]
# Unique Match:	52 of 129	(40.31%)
# Mirror Match:	51 of 92	(55.43%)
# Cluster Match:	54 of 100	(54.00%)

# %%
display.accuPlot([correct_us, correct_ms, correct_cs], [total_us, total_ms, total_cs], ["Unique Match", "Mirror Match", "Cluster Match"], ylim=(0.0,0.8))
