# %%
#Stupid hack to load files from sibling dir
import sys; import os
sys.path.insert(0, os.path.abspath('..'))

# %load_ext autoreload
# %autoreload 2

# %%
import fnmatch
import os
import matching
import weightMatrix
import display
import itertools

# %%
dt = 5
nb_tresholds = 50
tresholds_cluster = numpy.linspace(0.8,1.0, nb_tresholds)
tresholds_nocluster = numpy.linspace(0.4,0.8, nb_tresholds)
#tresholds_cluster = numpy.linspace(0.92,1.0, 1)
#tresholds_nocluster = numpy.linspace(0.6,0.8, 1)
directory = "Pittsburg2"
keypoint = "SIFT"
descriptor = "SIFT"
verbose = True

# %%
correct_us, total_us = matching.folderMatch(directory, dt, matching.uniqueMatch, tresholds_nocluster, keypoint, descriptor)

# %%
correct_ms, total_ms = matching.folderMatch(directory, dt, matching.mirrorMatch, tresholds_nocluster, keypoint, descriptor)

# %%
correct_cs, total_cs = matching.folderMatch(directory, dt, matching.clusterMatch, tresholds_cluster, keypoint, descriptor)

# %%
display.accuDetail([correct_us, correct_ms, correct_cs], [total_us, total_ms, total_cs], ["Unique Match", "Mirror Match", "Cluster Match"], treshold = 800)
# Out:
# [33, 39, 38]
# Unique Match:	803 of 956	(84.00%)
# Mirror Match:	804 of 899	(89.43%)
# Cluster Match:	806 of 974	(82.75%)

# %%
display.accuPlot([correct_us, correct_ms, correct_cs], [total_us, total_ms, total_cs], ["Unique Match", "Mirror Match", "Cluster Match"], ylim=0.9)
