# %%
#Stupid hack to load files from sibling dir
import sys; import os
sys.path.insert(0, os.path.abspath('..'))

# %load_ext autoreload
# %autoreload 2

# %%
import fnmatch
import os
import matching
import weightMatrix
import display
import itertools

# %%
dt = 20
directory = "Water"
keypoint = "SIFT"
descriptor = "SIFT"

# %%
accu_us = matching.folderMatch(directory, dt, matching.uniqueMatchFun, 0.52, keypoint, descriptor)
# Out:
# Number of matches:	1611	(distinct: 1343)
# Correct matches:	1390	(distinct: 1144)		[under 20px error]
# Success Rate:		86.28%	(distinct: 85.18%)

# %%
accu_bs = matching.folderMatch(directory, dt, matching.bothMatchFun, 0.5, keypoint, descriptor)
# Out:
# Number of matches:	1227	(distinct: 1025)
# Correct matches:	1085	(distinct: 897)		[under 20px error]
# Success Rate:		88.43%	(distinct: 87.51%)

# %%
accu_cs = matching.folderMatch(directory, dt, matching.clusterMatchFun, 0.9, keypoint, descriptor)
# Out:
# Number of matches:	1540	(distinct: 1265)
# Correct matches:	1423	(distinct: 1152)		[under 20px error]
# Success Rate:		92.40%	(distinct: 91.07%)

# %%
display.accuHist([accu_us,accu_bs,accu_cs],["Unique Match", "Mirror Match", "Cluster Match"])
