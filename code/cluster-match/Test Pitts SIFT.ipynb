# %%
#Stupid hack to load files from sibling dir
import sys; import os
sys.path.insert(0, os.path.abspath('..'))

# %load_ext autoreload
# %autoreload 2

# %%
import fnmatch
import os
import matching
import weightMatrix
import display
import itertools

# %%
dt = 20
directory = "Pittsburg"
keypoint = "SIFT"
descriptor = "SIFT"

# %%
accu_us = matching.folderMatch(directory, dt, matching.uniqueMatchFun, 0.58, keypoint, descriptor)
# Out:
# Number of matches:	2245	(distinct: 1597)
# Correct matches:	2180	(distinct: 1533)		[under 20px error]
# Success Rate:		97.10%	(distinct: 95.99%)

# %%
accu_bs = matching.folderMatch(directory, dt, matching.bothMatchFun, 0.42, keypoint, descriptor)
# Out:
# Number of matches:	1036	(distinct: 797)
# Correct matches:	1036	(distinct: 797)		[under 20px error]
# Success Rate:		100.00%	(distinct: 100.00%)

# %%
accu_cs = matching.folderMatch(directory, dt, matching.clusterMatchFun, 0.9, keypoint, descriptor)

# %%
display.accuHist([accu_us,accu_bs,accu_cs],["Unique Match", "Mirror Match", "Cluster Match"])
