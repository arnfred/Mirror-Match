# %%
#Stupid hack to load files from sibling dir
import sys; import os
sys.path.insert(0, os.path.abspath('..'))

# %load_ext autoreload
# %autoreload 2

# %%
import fnmatch
import os
import matching
import weightMatrix
import display
import itertools

# %%
dt = 5
nb_thresholds = 50
thresholds_cluster = numpy.linspace(0.8,1.0, nb_thresholds)
thresholds_nocluster = numpy.linspace(0.3,0.8, nb_thresholds)
#tresholds_cluster = numpy.linspace(0.92,1.0, 1)
#tresholds_nocluster = numpy.linspace(0.6,0.8, 1)
directory = "Accumulated"
keypoint = "SIFT"
descriptor = "SIFT"
verbose = True

# %%
correct_sift, total_sift = matching.folderMatch(directory, dt, matching.clusterMatch, thresholds_cluster, "SIFT", "SIFT")

# %%
correct_surf, total_surf = matching.folderMatch(directory, dt, matching.clusterMatch, thresholds_cluster, "SURF", "SURF")

# %%
correct_brief, total_brief = matching.folderMatch(directory, dt, matching.clusterMatch, thresholds_cluster, "HARRIS", "BRIEF")

# %%
display.accuDetail([correct_sift, correct_surf, correct_brief], [total_sift, total_surf, total_brief], ["SIFT", "SURF", "BRIEF"], treshold = 2000)
# Out:
# [23, 45, 47]
# SIFT:	2217 of 3259	(68.03%)
# SURF:	2276 of 5007	(45.46%)
# BRIEF:	2061 of 3683	(55.96%)

# %%
display.accuPlot([correct_sift, correct_surf, correct_brief], [total_sift, total_surf, total_brief], ["SIFT", "SURF", "BRIEF"], ylim=(0.4,1.01), xlim=10000)
