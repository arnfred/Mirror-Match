# %%
#Stupid hack to load files from sibling dir
import sys; import os
sys.path.insert(0, os.path.abspath('..'))

# %load_ext autoreload
# %autoreload 2

# %%
import fnmatch
import os
import matching
import weightMatrix
import display
import itertools

# %%
dt = 20
directory = "BOAT"

# %%
accu_cs = matching.folderMatch(directory, dt, matching.clusterMatchSIFT)
# Out:
# Number of matches:	2526	(distinct: 2241)
# Correct matches:	1905	(distinct: 1627)		[under 20px error]
# Success Rate:		75.42%	(distinct: 72.60%)

# %%
accu_us = matching.folderMatch(directory, dt, matching.uniqueMatchSIFT)
# Out:
# Number of matches:	2064	(distinct: 1752)
# Correct matches:	1958	(distinct: 1647)		[under 20px error]
# Success Rate:		94.86%	(distinct: 94.01%)

# %%
accu_bs = matching.folderMatch(directory, dt, matching.bothMatchSIFT)
# Out:
# Number of matches:	2014	(distinct: 1698)
# Correct matches:	1969	(distinct: 1654)		[under 20px error]
# Success Rate:		97.77%	(distinct: 97.41%)

# %%
nb_us = len(distances_us)
nb_correct_us = len([d for d in distances_us if d < dt])
nb_bs = len(distances_bs)
nb_correct_bs = len([d for d in distances_bs if d < dt])
print("Ratio of errors removed: %.2f" % (1 - ((nb_bs-nb_correct_bs)) / float(nb_us-nb_correct_us)))
print("Ratio of removed matches that were errors: %.2f" % (float((nb_us-nb_correct_us) - (nb_bs-nb_correct_bs))/(nb_us-nb_bs)))
# Out:
# Ratio of errors removed: 0.14
# Ratio of removed matches that were errors: 2.00

# %%
0
# Out:
# 0
