# %%
#Stupid hack to load files from sibling dir
import sys; import os
sys.path.insert(0, os.path.abspath('..'))

# %load_ext autoreload
# %autoreload 2

# %%
import features
import display
import isodata
import matching
import weightMatrix

# %%
paths, homography = matching.getACRPaths(2,"leuven")
paths
# Out:
# ['../../images/acr/leuven/img1.ppm', '../../images/acr/leuven/img2.ppm']

# %%
matches = matching.testMatch(paths, 
                             homography, 
                             matching.isodataMatch,
                             options = {
                                 "k_init" : 30,
                                 "max_iterations" : 20,
                                 "min_partition_size" : 10,
                                 "max_sd" : 40,
                                 "min_distance" : 25,
                                 #"verbose" : True
                             })
# Out:
# Median distance: 0.94
# Number of matches: 345

# %%
images = map(features.loadImage, paths)
display.matches(images[0], images[1], matches)
