# %%
#Stupid hack to load files from sibling dir
import sys; import os
sys.path.insert(0, os.path.abspath('..'))

# %load_ext autoreload
# %autoreload 2

# %%
import features
import display
import isodata
import matching
import weightMatrix

# %%
paths, homography = matching.getACRPaths(2,"leuven")
paths
# Out:
# ['../../images/acr/leuven/img1.ppm', '../../images/acr/leuven/img2.ppm']

# %%
matches, dist = matching.testMatch(paths, 
                             homography, 
                             matching.isodataMatch,
                             options = {
                                 "k_init" : 30,
                                 "max_iterations" : 20,
                                 "min_partition_size" : 10,
                                 "max_sd" : 40,
                                 "min_distance" : 25,
                                 "verbose" : True
                             })
# Out:
# Number of matches:	17	(distinct: 4)
# Correct matches:	17	(distinct: 4)		[under 5px error]
# Success Rate:		100.00%	(distinct: 100.00%)

# %%
images = map(features.loadImage, paths)
display.matchPoints(images[0], images[1], matches)

# %%
m_distinct = matching.getDistinctMatches(matches)
len(m_distinct)
# Out:
# 4

# %%
images = map(features.loadImage, paths)
display.matchPoints(images[0], images[1], m_distinct)
