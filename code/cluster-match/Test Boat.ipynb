# %%
#Stupid hack to load files from sibling dir
import sys; import os
sys.path.insert(0, os.path.abspath('..'))

# %load_ext autoreload
# %autoreload 2

# %%
import fnmatch
import os
import matching
import weightMatrix
import display
import itertools

# %%
dt = 20
directory = "Water"
keypoint = "HARRIS"
descriptor = "BRIEF"

# %%
accu_us = matching.folderMatch(directory, dt, matching.uniqueMatchFun, 0.7, keypoint, descriptor)
# Out:
# Number of matches:	595	(distinct: 539)
# Correct matches:	449	(distinct: 394)		[under 20px error]
# Success Rate:		75.46%	(distinct: 73.10%)

# %%
accu_bs = matching.folderMatch(directory, dt, matching.bothMatchFun, 0.74, keypoint, descriptor)
# Out:
# Number of matches:	259	(distinct: 244)
# Correct matches:	224	(distinct: 210)		[under 20px error]
# Success Rate:		86.49%	(distinct: 86.07%)

# %%
accu_cs = matching.folderMatch(directory, dt, matching.clusterMatchFun, 0.02, keypoint, descriptor)

# %%
nb_us = len(distances_us)
nb_correct_us = len([d for d in distances_us if d < dt])
nb_bs = len(distances_bs)
nb_correct_bs = len([d for d in distances_bs if d < dt])
print("Ratio of errors removed: %.2f" % (1 - ((nb_bs-nb_correct_bs)) / float(nb_us-nb_correct_us)))
print("Ratio of removed matches that were errors: %.2f" % (float((nb_us-nb_correct_us) - (nb_bs-nb_correct_bs))/(nb_us-nb_bs)))

# %%
0
