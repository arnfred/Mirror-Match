# %%
#Stupid hack to load files from sibling dir
import sys; import os
sys.path.insert(0, os.path.abspath('..'))

# %load_ext autoreload
# %autoreload 2

# %%
import fnmatch
import os
import matching
import weightMatrix
import display
import itertools

# %%
dt = 5
directory = "trees6"
keypoint = "SIFT"
descriptor = "SIFT"

# %%
accu_us = matching.folderMatch(directory, dt, matching.uniqueMatchFun, 0.58, keypoint, descriptor)
# Out:
# Number of matches:	90	(distinct: 83)
# Correct matches:	72	(distinct: 65)		[under 5px error]
# Success Rate:		80.00%	(distinct: 78.31%)

# %%
accu_bs = matching.folderMatch(directory, dt, matching.bothMatchFun, 0.62, keypoint, descriptor)
# Out:
# Number of matches:	79	(distinct: 72)
# Correct matches:	65	(distinct: 58)		[under 5px error]
# Success Rate:		82.28%	(distinct: 80.56%)

# %%
accu_cs = matching.folderMatch(directory, dt, matching.clusterMatchFun, 0.9, keypoint, descriptor)
# Out:
# Number of matches:	111	(distinct: 104)
# Correct matches:	75	(distinct: 68)		[under 5px error]
# Success Rate:		67.57%	(distinct: 65.38%)

# %%
display.accuHist([accu_us,accu_bs,accu_cs],["Unique Match", "Mirror Match", "Cluster Match"])
