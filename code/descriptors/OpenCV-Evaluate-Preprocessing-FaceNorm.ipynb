# %%
import evaluate
import os
import fnmatch
import display
import numpy
import features

# testset = "../../images/testsets/WC818C/"
testset = "../../images/testsets/small_test/"

# Get a list of all images
paths = [testset + f for (_,_,filenames) in os.walk(testset) for f in fnmatch.filter(filenames, "*.png")]

# %%
# Create a function for comparing ratios for use in comparisons
def comp(i, s, u) :
    n = len(i)/2
    treshold_dist = sorted(s)[n]
    treshold_ratio = sorted(u)[n]
    dist = [s_i for (s_i,u_i) in zip(s,u) if (s_i <= treshold_dist and u_i <= treshold_ratio)]

    return numpy.mean(dist[:10])

# %%
#Stupid hack to load files from sibling dir
import sys; import os
sys.path.insert(0, os.path.abspath('..'))
                       
import preprocessing.preprocessing as pp

# Get all labels
labels = map(features.getLabel, paths)

# Load all images
# images = map(lambda i : pp.faceNorm(features.loadImage(i),0.6), paths)
gray()
images = map(features.loadImage, paths)
imshow(images[0])

# %%
# %time result = evaluate.imageToImage(images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ###
# ##
# CPU times: user 0.45 s, sys: 0.01 s, total: 0.46 s
# Wall time: 0.29 s
#
# Mean(same): 49.124
# Mean(diff): 53.845
# Difference: 8.767%

# %%
processed_images = map(lambda i : pp.faceNorm(i,0.04), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ##
# ##
# #
# CPU times: user 1.19 s, sys: 0.02 s, total: 1.21 s
# Wall time: 0.57 s
#
# Mean(same): 66.832
# Mean(diff): 70.220
# Difference: 4.825%

# %%
processed_images = map(lambda i : pp.faceNorm(i,0.08), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ##
# ##
# #
# CPU times: user 1.14 s, sys: 0.01 s, total: 1.14 s
# Wall time: 0.56 s
#
# Mean(same): 67.111
# Mean(diff): 69.671
# Difference: 3.674%

# %%
processed_images = map(lambda i : pp.faceNorm(i,0.12), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ##
# ##
# #
# CPU times: user 1.00 s, sys: 0.04 s, total: 1.04 s
# Wall time: 0.51 s
#
# Mean(same): 66.830
# Mean(diff): 69.965
# Difference: 4.481%

# %%
processed_images = map(lambda i : pp.faceNorm(i,0.16), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ##
# ##
# #
# CPU times: user 0.93 s, sys: 0.00 s, total: 0.93 s
# Wall time: 0.46 s
#
# Mean(same): 66.682
# Mean(diff): 69.841
# Difference: 4.522%

# %%
processed_images = map(lambda i : pp.faceNorm(i,0.2), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ##
# ##
# #
# CPU times: user 0.82 s, sys: 0.01 s, total: 0.82 s
# Wall time: 0.40 s
#
# Mean(same): 66.477
# Mean(diff): 70.156
# Difference: 5.244%

# %%
processed_images = map(lambda i : pp.faceNorm(i,0.25), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ##
# ##
# #
# CPU times: user 0.69 s, sys: 0.04 s, total: 0.74 s
# Wall time: 0.40 s
#
# Mean(same): 66.377
# Mean(diff): 69.867
# Difference: 4.995%

# %%
processed_images = map(lambda i : pp.faceNorm(i,0.3), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ##
# ##
# #
# CPU times: user 0.60 s, sys: 0.04 s, total: 0.64 s
# Wall time: 0.32 s
#
# Mean(same): 66.320
# Mean(diff): 69.910
# Difference: 5.136%

# %%
processed_images = map(lambda i : pp.faceNorm(i,0.35), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ##
# ##
# #
# CPU times: user 0.57 s, sys: 0.01 s, total: 0.58 s
# Wall time: 0.30 s
#
# Mean(same): 66.457
# Mean(diff): 70.093
# Difference: 5.188%

# %%
processed_images = map(lambda i : pp.faceNorm(i,0.4), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ##
# ##
# #
# CPU times: user 0.51 s, sys: 0.01 s, total: 0.52 s
# Wall time: 0.27 s
#
# Mean(same): 66.335
# Mean(diff): 70.113
# Difference: 5.388%

# %%
processed_images = map(lambda i : pp.faceNorm(i,0.5), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ##
# ###
# CPU times: user 0.42 s, sys: 0.04 s, total: 0.45 s
# Wall time: 0.24 s
#
# Mean(same): 66.144
# Mean(diff): 70.215
# Difference: 5.798%

# %%
processed_images = map(lambda i : pp.faceNorm(i,0.6), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ###
# ##
# CPU times: user 0.39 s, sys: 0.01 s, total: 0.40 s
# Wall time: 0.21 s
# Mean(same): 66.562
# Mean(diff): 70.398
# Difference: 5.449%

# %%
processed_images = map(lambda i : pp.faceNorm(i,0.8), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ###
# ##
# CPU times: user 0.33 s, sys: 0.02 s, total: 0.35 s
# Wall time: 0.19 s
#
# Mean(same): 66.498
# Mean(diff): 70.653
# Difference: 5.882%

# %%
processed_images = map(lambda i : pp.faceNorm(i,1), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ###
# ##
# CPU times: user 0.28 s, sys: 0.03 s, total: 0.31 s
# Wall time: 0.17 s
#
# Mean(same): 66.319
# Mean(diff): 70.619
# Difference: 6.089%

# %%
processed_images = map(lambda i : pp.faceNorm(i,1.5), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ###
# ##
# CPU times: user 0.23 s, sys: 0.04 s, total: 0.27 s
# Wall time: 0.15 s
#
# Mean(same): 66.458
# Mean(diff): 70.882
# Difference: 6.242%

# %%
processed_images = map(lambda i : pp.faceNorm(i,2), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ###
# ##
# CPU times: user 0.21 s, sys: 0.03 s, total: 0.24 s
# Wall time: 0.13 s
#
# Mean(same): 66.427
# Mean(diff): 71.157
# Difference: 6.648%

# %%
processed_images = map(lambda i : pp.faceNorm(i,2.5), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ####
# #
# CPU times: user 0.21 s, sys: 0.03 s, total: 0.24 s
# Wall time: 0.13 s
#
# Mean(same): 66.425
# Mean(diff): 71.165
# Difference: 6.660%

# %%
processed_images = map(lambda i : pp.faceNorm(i,3), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ####
# #
# CPU times: user 0.20 s, sys: 0.02 s, total: 0.22 s
# Wall time: 0.12 s
#
# Mean(same): 66.393
# Mean(diff): 71.196
# Difference: 6.746%

# %%
processed_images = map(lambda i : pp.faceNorm(i,3.5), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ####
# #
# CPU times: user 0.20 s, sys: 0.01 s, total: 0.22 s
# Wall time: 0.12 s
#
# Mean(same): 66.571
# Mean(diff): 71.032
# Difference: 6.280%

# %%
processed_images = map(lambda i : pp.faceNorm(i,4), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ####
# #
# CPU times: user 0.17 s, sys: 0.04 s, total: 0.21 s
# Wall time: 0.12 s
#
# Mean(same): 66.533
# Mean(diff): 71.151
# Difference: 6.489%
