# %%
import evaluate
import os
import fnmatch
import display
import numpy
import features

# testset = "../../images/testsets/WC818C/"
testset = "../../images/testsets/small_test/"

# Get a list of all images
paths = [testset + f for (_,_,filenames) in os.walk(testset) for f in fnmatch.filter(filenames, "*.png")]

# %%
# Create a function for comparing ratios for use in comparisons
def comp(i, s, u) :
    n = len(i)/2
    treshold_dist = sorted(s)[n]
    treshold_ratio = sorted(u)[n]
    dist = [s_i for (s_i,u_i) in zip(s,u) if (s_i <= treshold_dist and u_i <= treshold_ratio)]

    return numpy.mean(dist)

# %%
#Stupid hack to load files from sibling dir
import sys; import os
sys.path.insert(0, os.path.abspath('..'))
                       
import preprocessing.preprocessing as pp

# Get all labels
labels = map(features.getLabel, paths)

# Load all images
# images = map(lambda i : pp.faceNorm(features.loadImage(i),0.6), paths)
gray()
images = map(features.loadImage, paths)
imshow(images[0])

# %%
# %time result = evaluate.imageToImage(images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ##
# ##
# #
# CPU times: user 0.44 s, sys: 0.04 s, total: 0.48 s
# Wall time: 0.30 s
#
# Mean(same):		49.885
# Mean(diff):		54.736
# Diff of means:		4.851
# Standard deviation:	6.751
# # of sd's:		0.719

# %%
processed_images = map(lambda i : pp.faceNorm(i,0.04), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ##
# ##
# #
# CPU times: user 1.20 s, sys: 0.02 s, total: 1.22 s
# Wall time: 0.57 s
#
# Mean(same):		67.147
# Mean(diff):		70.284
# Diff of means:		3.138
# Standard deviation:	5.661
# # of sd's:		0.554

# %%
processed_images = map(lambda i : pp.faceNorm(i,0.08), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ##
# ##
# #
# CPU times: user 1.12 s, sys: 0.04 s, total: 1.15 s
# Wall time: 0.56 s
#
# Mean(same):		66.802
# Mean(diff):		69.992
# Diff of means:		3.190
# Standard deviation:	5.715
# # of sd's:		0.558

# %%
processed_images = map(lambda i : pp.faceNorm(i,0.12), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ##
# ##
# #
# CPU times: user 1.01 s, sys: 0.02 s, total: 1.02 s
# Wall time: 0.50 s
#
# Mean(same):		66.567
# Mean(diff):		69.913
# Diff of means:		3.346
# Standard deviation:	5.732
# # of sd's:		0.584

# %%
processed_images = map(lambda i : pp.faceNorm(i,0.16), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ##
# ##
# #
# CPU times: user 0.90 s, sys: 0.03 s, total: 0.92 s
# Wall time: 0.46 s
#
# Mean(same):		66.429
# Mean(diff):		69.924
# Diff of means:		3.494
# Standard deviation:	5.830
# # of sd's:		0.599

# %%
processed_images = map(lambda i : pp.faceNorm(i,0.2), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ##
# ##
# #
# CPU times: user 0.80 s, sys: 0.03 s, total: 0.83 s
# Wall time: 0.41 s
#
# Mean(same):		66.296
# Mean(diff):		69.930
# Diff of means:		3.633
# Standard deviation:	5.924
# # of sd's:		0.613

# %%
processed_images = map(lambda i : pp.faceNorm(i,0.25), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ##
# ##
# #
# CPU times: user 0.72 s, sys: 0.02 s, total: 0.74 s
# Wall time: 0.39 s
#
# Mean(same):		65.938
# Mean(diff):		69.910
# Diff of means:		3.971
# Standard deviation:	5.987
# # of sd's:		0.663

# %%
processed_images = map(lambda i : pp.faceNorm(i,0.3), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ##
# ##
# #
# CPU times: user 0.62 s, sys: 0.02 s, total: 0.64 s
# Wall time: 0.32 s
#
# Mean(same):		65.949
# Mean(diff):		69.919
# Diff of means:		3.970
# Standard deviation:	6.085
# # of sd's:		0.652

# %%
processed_images = map(lambda i : pp.faceNorm(i,0.35), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ##
# ##
# #
# CPU times: user 0.56 s, sys: 0.02 s, total: 0.59 s
# Wall time: 0.32 s
#
# Mean(same):		65.942
# Mean(diff):		69.950
# Diff of means:		4.008
# Standard deviation:	6.177
# # of sd's:		0.649

# %%
processed_images = map(lambda i : pp.faceNorm(i,0.4), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ##
# ##
# #
# CPU times: user 0.50 s, sys: 0.03 s, total: 0.54 s
# Wall time: 0.30 s
#
# Mean(same):		66.189
# Mean(diff):		70.058
# Diff of means:		3.869
# Standard deviation:	6.237
# # of sd's:		0.620

# %%
processed_images = map(lambda i : pp.faceNorm(i,0.5), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ##
# ###
# CPU times: user 0.44 s, sys: 0.02 s, total: 0.45 s
# Wall time: 0.25 s
#
# Mean(same):		66.165
# Mean(diff):		70.321
# Diff of means:		4.156
# Standard deviation:	6.462
# # of sd's:		0.643

# %%
processed_images = map(lambda i : pp.faceNorm(i,0.6), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ###
# ##
# CPU times: user 0.39 s, sys: 0.02 s, total: 0.41 s
# Wall time: 0.22 s
#
# Mean(same):		66.375
# Mean(diff):		70.293
# Diff of means:		3.918
# Standard deviation:	6.598
# # of sd's:		0.594

# %%
processed_images = map(lambda i : pp.faceNorm(i,0.8), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ###
# ##
# CPU times: user 0.32 s, sys: 0.02 s, total: 0.34 s
# Wall time: 0.19 s
#
# Mean(same):		66.443
# Mean(diff):		70.556
# Diff of means:		4.113
# Standard deviation:	6.897
# # of sd's:		0.596

# %%
processed_images = map(lambda i : pp.faceNorm(i,1), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ###
# ##
# CPU times: user 0.30 s, sys: 0.02 s, total: 0.32 s
# Wall time: 0.20 s
#
# Mean(same):		66.256
# Mean(diff):		70.505
# Diff of means:		4.248
# Standard deviation:	6.909
# # of sd's:		0.615

# %%
processed_images = map(lambda i : pp.faceNorm(i,1.5), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ###
# ##
# CPU times: user 0.25 s, sys: 0.02 s, total: 0.28 s
# Wall time: 0.16 s
#
# Mean(same):		66.391
# Mean(diff):		70.822
# Diff of means:		4.430
# Standard deviation:	6.993
# # of sd's:		0.634

# %%
processed_images = map(lambda i : pp.faceNorm(i,2), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ###
# ##
# CPU times: user 0.23 s, sys: 0.01 s, total: 0.24 s
# Wall time: 0.13 s
#
# Mean(same):		66.497
# Mean(diff):		71.051
# Diff of means:		4.553
# Standard deviation:	7.182
# # of sd's:		0.634

# %%
processed_images = map(lambda i : pp.faceNorm(i,2.5), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ####
# #
# CPU times: user 0.22 s, sys: 0.00 s, total: 0.22 s
# Wall time: 0.13 s
#
# Mean(same):		66.432
# Mean(diff):		71.135
# Diff of means:		4.704
# Standard deviation:	7.289
# # of sd's:		0.645

# %%
processed_images = map(lambda i : pp.faceNorm(i,3), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ####
# #
# CPU times: user 0.20 s, sys: 0.02 s, total: 0.22 s
# Wall time: 0.12 s
#
# Mean(same):		66.425
# Mean(diff):		71.106
# Diff of means:		4.682
# Standard deviation:	7.245
# # of sd's:		0.646

# %%
processed_images = map(lambda i : pp.faceNorm(i,3.5), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ####
# #
# CPU times: user 0.17 s, sys: 0.04 s, total: 0.21 s
# Wall time: 0.13 s
#
# Mean(same):		66.428
# Mean(diff):		71.051
# Diff of means:		4.623
# Standard deviation:	7.290
# # of sd's:		0.634

# %%
processed_images = map(lambda i : pp.faceNorm(i,4), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ####
# #
# CPU times: user 0.19 s, sys: 0.02 s, total: 0.21 s
# Wall time: 0.12 s
#
# Mean(same):		66.606
# Mean(diff):		71.066
# Diff of means:		4.460
# Standard deviation:	7.389
# # of sd's:		0.604

# %%
# %load_ext autoreload
# %autoreload 2
