# %%
import evaluate
import os
import fnmatch
import display
import numpy
import features

# testset = "../../images/testsets/WC818C/"
testset = "../../images/testsets/small_test/"

# Get a list of all images
paths = [testset + f for (_,_,filenames) in os.walk(testset) for f in fnmatch.filter(filenames, "*.png")]

# %%
# Create a function for comparing ratios for use in comparisons
def comp(i, s, u) :
    n = len(i)/2
    treshold_dist = sorted(s)[n]
    treshold_ratio = sorted(u)[n]
    dist = [s_i for (s_i,u_i) in zip(s,u) if (s_i <= treshold_dist and u_i <= treshold_ratio)]

    return numpy.mean(dist[:10])

# %%
#Stupid hack to load files from sibling dir
import sys; import os
sys.path.insert(0, os.path.abspath('..'))
                       
import preprocessing.preprocessing as pp

# Get all labels
labels = map(features.getLabel, paths)

# Load all images
# images = map(lambda i : pp.faceNorm(features.loadImage(i),0.6), paths)
gray()
images = map(features.loadImage, paths)
imshow(images[0])

# %%
# %time result = evaluate.imageToImage(images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ##
# ##
# #
# CPU times: user 0.42 s, sys: 0.04 s, total: 0.46 s
# Wall time: 0.30 s
#
# Mean(same): 49.124
# Mean(diff): 53.845
# Difference: 8.767%

# %%
processed_images = map(lambda i : pp.tanTriggs(i,0.04), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ##
# ##
# #
# CPU times: user 1.14 s, sys: 0.03 s, total: 1.18 s
# Wall time: 0.55 s
#
# Mean(same): 70.593
# Mean(diff): 73.666
# Difference: 4.172%

# %%
processed_images = map(lambda i : pp.tanTriggs(i,0.08), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ##
# ##
# #
# CPU times: user 1.13 s, sys: 0.02 s, total: 1.15 s
# Wall time: 0.54 s
#
# Mean(same): 70.757
# Mean(diff): 73.908
# Difference: 4.263%

# %%
processed_images = map(lambda i : pp.tanTriggs(i,0.12), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ##
# ##
# #
# CPU times: user 1.13 s, sys: 0.01 s, total: 1.14 s
# Wall time: 0.53 s
#
# Mean(same): 70.944
# Mean(diff): 73.727
# Difference: 3.776%

# %%
processed_images = map(lambda i : pp.tanTriggs(i,0.16), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ##
# ##
# #
# CPU times: user 1.10 s, sys: 0.02 s, total: 1.12 s
# Wall time: 0.53 s
#
# Mean(same): 71.143
# Mean(diff): 73.835
# Difference: 3.646%

# %%
processed_images = map(lambda i : pp.tanTriggs(i,0.2), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ##
# ##
# #
# CPU times: user 1.07 s, sys: 0.03 s, total: 1.10 s
# Wall time: 0.52 s
#
# Mean(same): 70.961
# Mean(diff): 73.796
# Difference: 3.842%

# %%
processed_images = map(lambda i : pp.tanTriggs(i,0.25), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ##
# ##
# #
# CPU times: user 1.09 s, sys: 0.01 s, total: 1.10 s
# Wall time: 0.53 s
#
# Mean(same): 71.084
# Mean(diff): 73.834
# Difference: 3.724%

# %%
processed_images = map(lambda i : pp.tanTriggs(i,0.3), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ##
# ##
# #
# CPU times: user 1.05 s, sys: 0.02 s, total: 1.07 s
# Wall time: 0.51 s
#
# Mean(same): 71.181
# Mean(diff): 73.823
# Difference: 3.579%

# %%
processed_images = map(lambda i : pp.tanTriggs(i,0.35), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ##
# ##
# #
# CPU times: user 1.01 s, sys: 0.03 s, total: 1.04 s
# Wall time: 0.49 s
#
# Mean(same): 71.128
# Mean(diff): 73.926
# Difference: 3.785%

# %%
processed_images = map(lambda i : pp.tanTriggs(i,0.4), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ##
# ##
# #
# CPU times: user 1.01 s, sys: 0.02 s, total: 1.03 s
# Wall time: 0.50 s
#
# Mean(same): 71.193
# Mean(diff): 73.955
# Difference: 3.735%

# %%
processed_images = map(lambda i : pp.tanTriggs(i,0.5), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ##
# ##
# #
# CPU times: user 0.95 s, sys: 0.01 s, total: 0.96 s
# Wall time: 0.47 s
#
# Mean(same): 71.361
# Mean(diff): 74.019
# Difference: 3.592%

# %%
processed_images = map(lambda i : pp.tanTriggs(i,0.6), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ##
# ##
# #
# CPU times: user 0.91 s, sys: 0.02 s, total: 0.93 s
# Wall time: 0.47 s
#
# Mean(same): 71.695
# Mean(diff): 74.350
# Difference: 3.571%

# %%
processed_images = map(lambda i : pp.tanTriggs(i,0.8), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ##
# ##
# #
# CPU times: user 0.80 s, sys: 0.04 s, total: 0.84 s
# Wall time: 0.41 s
#
# Mean(same): 72.317
# Mean(diff): 74.988
# Difference: 3.561%

# %%
processed_images = map(lambda i : pp.tanTriggs(i,1), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ##
# ##
# #
# CPU times: user 0.75 s, sys: 0.01 s, total: 0.76 s
# Wall time: 0.38 s
#
# Mean(same): 72.640
# Mean(diff): 75.793
# Difference: 4.160%

# %%
processed_images = map(lambda i : pp.tanTriggs(i,1.5), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ##
# ##
# #
# CPU times: user 0.58 s, sys: 0.02 s, total: 0.60 s
# Wall time: 0.31 s
#
# Mean(same): 73.741
# Mean(diff): 77.019
# Difference: 4.255%

# %%
processed_images = map(lambda i : pp.tanTriggs(i,2), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ###
# ##
# CPU times: user 0.48 s, sys: 0.01 s, total: 0.49 s
# Wall time: 0.27 s
#
# Mean(same): 74.302
# Mean(diff): 78.134
# Difference: 4.904%

# %%
processed_images = map(lambda i : pp.tanTriggs(i,2.5), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ###
# ##
# CPU times: user 0.42 s, sys: 0.01 s, total: 0.43 s
# Wall time: 0.23 s
#
# Mean(same): 75.214
# Mean(diff): 79.025
# Difference: 4.823%

# %%
processed_images = map(lambda i : pp.tanTriggs(i,3), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ###
# ##
# CPU times: user 0.37 s, sys: 0.01 s, total: 0.38 s
# Wall time: 0.20 s
#
# Mean(same): 75.733
# Mean(diff): 79.459
# Difference: 4.689%

# %%
processed_images = map(lambda i : pp.tanTriggs(i,3.5), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ###
# ##
# CPU times: user 0.34 s, sys: 0.02 s, total: 0.35 s
# Wall time: 0.19 s
#
# Mean(same): 76.056
# Mean(diff): 80.256
# Difference: 5.233%

# %%
processed_images = map(lambda i : pp.tanTriggs(i,4), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ###
# ##
# CPU times: user 0.32 s, sys: 0.01 s, total: 0.33 s
# Wall time: 0.18 s
#
# Mean(same): 76.594
# Mean(diff): 80.830
# Difference: 5.240%

# %%
processed_images = map(lambda i : pp.tanTriggs(i,5), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ###
# ##
# CPU times: user 0.31 s, sys: 0.01 s, total: 0.32 s
# Wall time: 0.19 s
#
# Mean(same): 77.017
# Mean(diff): 81.563
# Difference: 5.573%

# %%
processed_images = map(lambda i : pp.tanTriggs(i,6), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ###
# ##
# CPU times: user 0.28 s, sys: 0.03 s, total: 0.30 s
# Wall time: 0.17 s
#
# Mean(same): 77.743
# Mean(diff): 81.720
# Difference: 4.867%

# %%
processed_images = map(lambda i : pp.tanTriggs(i,7), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ###
# ##
# CPU times: user 0.30 s, sys: 0.00 s, total: 0.30 s
# Wall time: 0.16 s
#
# Mean(same): 77.413
# Mean(diff): 81.586
# Difference: 5.116%

# %%
processed_images = map(lambda i : pp.tanTriggs(i,8), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ###
# ##
# CPU times: user 0.26 s, sys: 0.04 s, total: 0.29 s
# Wall time: 0.16 s
#
# Mean(same): 77.592
# Mean(diff): 82.116
# Difference: 5.509%

# %%
processed_images = map(lambda i : pp.tanTriggs(i,9), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ###
# ##
# CPU times: user 0.27 s, sys: 0.02 s, total: 0.29 s
# Wall time: 0.16 s
#
# Mean(same): 77.725
# Mean(diff): 81.910
# Difference: 5.109%

# %%
processed_images = map(lambda i : pp.tanTriggs(i,10), images)
# %time result = evaluate.imageToImage(processed_images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
