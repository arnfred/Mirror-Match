# %%
import evaluate
import os
import fnmatch
import display
import numpy

# testset = "../../images/testsets/WC818C/"
testset = "../../images/testsets/small_test/"

# Get a list of all images
paths = [testset + f for (_,_,filenames) in os.walk(testset) for f in fnmatch.filter(filenames, "*.png")]

# %%
# Create a function for comparing ratios for use in comparisons
def comp(i, s, u) : 
    n = len(i)/2
    return numpy.mean(sorted(u)[0:n])

# %%
# %time result = evaluate.imageToImage(paths, "SIFT", "SIFT", comp)
print
display.scoreHist(result)
# Out:
# =====
# ###
# ##
# CPU times: user 1.00 s, sys: 0.04 s, total: 1.04 s
# Wall time: 0.81 s
#
# Mean(same): 0.883
# Mean(diff): 0.889
# Difference: 0.006

# %%
# %time result = evaluate.imageToImage(paths, "SURF", "SURF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ####
# #
# CPU times: user 0.77 s, sys: 0.06 s, total: 0.83 s
# Wall time: 0.35 s
#
# Mean(same): 0.852
# Mean(diff): 0.858
# Difference: 0.006

# %%
# First test with default scoring:
# %time result = evaluate.imageToImage(paths, "ORB", "ORB", comp)
print
display.scoreHist(result)
# Out:
# =====
# ###
# ##
# CPU times: user 0.46 s, sys: 0.04 s, total: 0.50 s
# Wall time: 0.29 s
#
# Mean(same): 0.879
# Mean(diff): 0.889
# Difference: 0.010

# %%
# %time result = evaluate.imageToImage(paths, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ###
# ##
# CPU times: user 0.47 s, sys: 0.02 s, total: 0.50 s
# Wall time: 0.28 s
#
# Mean(same): 0.905
# Mean(diff): 0.913
# Difference: 0.008

# %%
# %time result = evaluate.imageToImage(paths, "ORB", "BRISK", comp)
print
display.scoreHist(result)
# Out:
# =====
# #####
# CPU times: user 8.96 s, sys: 0.38 s, total: 9.34 s
# Wall time: 9.27 s
#
# Mean(same): 0.888
# Mean(diff): 0.906
# Difference: 0.018

# %%
# %time result = evaluate.imageToImage(paths, "BRISK", "BRISK", comp)
print
display.scoreHist(result)
# Out:
# =====
# #####
# CPU times: user 17.68 s, sys: 0.72 s, total: 18.40 s
# Wall time: 18.35 s
#
# Mean(same): 0.866
# Mean(diff): 0.866
# Difference: -0.000

# %%
# %load_ext autoreload
# %autoreload 2
