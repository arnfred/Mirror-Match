# %%
import evaluate
import os
import fnmatch
import display
import numpy
import features
import cv2

# testset = "../../images/testsets/WC818C/"
testset = "../../images/testsets/small_test/"

# Get a list of all images
paths = [testset + f for (_,_,filenames) in os.walk(testset) for f in fnmatch.filter(filenames, "*.png")]
images = [cv2.imread(path) for path in paths]
labels = map(features.getLabel, paths)

# %%
# Create a function for comparing ratios for use in comparisons
def comp(i, s, u) : 
    return numpy.mean(s)

# %%
# %time result = evaluate.imageToImage(images, labels, "SIFT", "SIFT", comp)
print
display.scoreHist(result)
# Out:
# =====
# ###
# ##
# CPU times: user 0.92 s, sys: 0.02 s, total: 0.93 s
# Wall time: 0.71 s
#
# Mean(same):		355.747
# Mean(diff):		358.085
# Diff of means:		2.338
# Standard deviation:	14.425
# # of sd's:		0.162

# %%
# %time result = evaluate.imageToImage(images, labels, "SURF", "SURF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ####
# #
# CPU times: user 0.75 s, sys: 0.03 s, total: 0.78 s
# Wall time: 0.31 s
#
# Mean(same):		0.388
# Mean(diff):		0.391
# Diff of means:		0.003
# Standard deviation:	0.018
# # of sd's:		0.172

# %%
# First test with default scoring:
# %time result = evaluate.imageToImage(images, labels, "ORB", "ORB", comp)
print
display.scoreHist(result)
# Out:
# =====
# ###
# ##
# CPU times: user 0.42 s, sys: 0.03 s, total: 0.45 s
# Wall time: 0.24 s
#
# Mean(same):		68.868
# Mean(diff):		70.208
# Diff of means:		1.340
# Standard deviation:	4.355
# # of sd's:		0.308

# %%
# %time result = evaluate.imageToImage(images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ###
# ##
# CPU times: user 0.42 s, sys: 0.02 s, total: 0.44 s
# Wall time: 0.22 s
#
# Mean(same):		62.096
# Mean(diff):		65.930
# Diff of means:		3.835
# Standard deviation:	6.746
# # of sd's:		0.568

# %%
# %time result = evaluate.imageToImage(images, labels, "ORB", "BRISK", comp)
print
display.scoreHist(result)
# Out:
# =====
# #####
# CPU times: user 8.94 s, sys: 0.40 s, total: 9.34 s
# Wall time: 9.27 s
#
# Mean(same):		159.926
# Mean(diff):		168.217
# Diff of means:		8.291
# Standard deviation:	14.795
# # of sd's:		0.560

# %%
# %load_ext autoreload
# %autoreload 2
