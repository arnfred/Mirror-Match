# %%
import evaluate
import os
import fnmatch
import display
import numpy
import features
import cv2

# testset = "../../images/testsets/WC818C/"
testset = "../../images/testsets/small_test/"

# Get a list of all images
paths = [testset + f for (_,_,filenames) in os.walk(testset) for f in fnmatch.filter(filenames, "*.png")]
images = [cv2.imread(path) for path in paths]
labels = map(features.getLabel, paths)

# %%
# Create a function for comparing ratios for use in comparisons
def comp(i, s, u) : 
    n = len(i)/2
    return numpy.mean(sorted(s)[:n])

# %%
# %time result = evaluate.imageToImage(images, labels, "SIFT", "SIFT", comp)
print
display.scoreHist(result)
# Out:
# =====
# ###
# ##
# CPU times: user 0.92 s, sys: 0.04 s, total: 0.96 s
# Wall time: 0.73 s
#
# Mean(same):		311.623
# Mean(diff):		314.642
# Diff of means:		3.020
# Standard deviation:	20.630
# # of sd's:		0.146

# %%
# %time result = evaluate.imageToImage(images, labels, "SURF", "SURF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ####
# #
# CPU times: user 0.77 s, sys: 0.02 s, total: 0.79 s
# Wall time: 0.32 s
#
# Mean(same):		0.316
# Mean(diff):		0.320
# Diff of means:		0.003
# Standard deviation:	0.024
# # of sd's:		0.146

# %%
# First test with default scoring:
# %time result = evaluate.imageToImage(images, labels, "ORB", "ORB", comp)
print
display.scoreHist(result)
# Out:
# =====
# ###
# ##
# CPU times: user 0.45 s, sys: 0.02 s, total: 0.47 s
# Wall time: 0.25 s
#
# Mean(same):		59.151
# Mean(diff):		61.158
# Diff of means:		2.007
# Standard deviation:	4.477
# # of sd's:		0.448

# %%
# %time result = evaluate.imageToImage(images, labels, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ###
# ##
# CPU times: user 0.43 s, sys: 0.02 s, total: 0.45 s
# Wall time: 0.22 s
#
# Mean(same):		50.361
# Mean(diff):		55.491
# Diff of means:		5.130
# Standard deviation:	6.743
# # of sd's:		0.761

# %%
# %time result = evaluate.imageToImage(images, labels, "ORB", "BRISK", comp)
print
display.scoreHist(result)
# Out:
# =====
# #####
# CPU times: user 8.98 s, sys: 0.31 s, total: 9.30 s
# Wall time: 9.22 s
#
# Mean(same):		143.105
# Mean(diff):		153.757
# Diff of means:		10.652
# Standard deviation:	15.969
# # of sd's:		0.667

# %%
# %load_ext autoreload
# %autoreload 2
