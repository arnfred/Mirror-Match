# %%
import evaluate
import os
import fnmatch
import display
import numpy

# testset = "../../images/testsets/WC818C/"
testset = "../../images/testsets/small_test/"

# Get a list of all images
paths = [testset + f for (_,_,filenames) in os.walk(testset) for f in fnmatch.filter(filenames, "*.png")]

# %%
# Create a function for comparing ratios for use in comparisons
def comp(i, s, u) : 
    n = len(i)/2
    return numpy.mean(sorted(i)[0:n])

# %%
# %time result = evaluate.imageToImage(paths, "SIFT", "SIFT", comp)
print
display.scoreHist(result)
# Out:
# =====
# ###
# ##
# CPU times: user 0.93 s, sys: 0.10 s, total: 1.03 s
# Wall time: 0.80 s
#
# Mean(same): 31.382
# Mean(diff): 31.231
# Difference: -0.151

# %%
# %time result = evaluate.imageToImage(paths, "SURF", "SURF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ####
# #
# CPU times: user 0.80 s, sys: 0.02 s, total: 0.83 s
# Wall time: 0.35 s
#
# Mean(same): 23.837
# Mean(diff): 24.064
# Difference: 0.227

# %%
# First test with default scoring:
# %time result = evaluate.imageToImage(paths, "ORB", "ORB", comp)
print
display.scoreHist(result)
# Out:
# =====
# ###
# ##
# CPU times: user 0.48 s, sys: 0.02 s, total: 0.50 s
# Wall time: 0.29 s
#
# Mean(same): 35.291
# Mean(diff): 35.507
# Difference: 0.215

# %%
# %time result = evaluate.imageToImage(paths, "ORB", "BRIEF", comp)
print
display.scoreHist(result)
# Out:
# =====
# ###
# ##
# CPU times: user 0.46 s, sys: 0.03 s, total: 0.49 s
# Wall time: 0.27 s
#
# Mean(same): 28.219
# Mean(diff): 28.894
# Difference: 0.675

# %%
# %time result = evaluate.imageToImage(paths, "ORB", "BRISK", comp)
print
display.scoreHist(result)
# Out:
# =====
# #####
# CPU times: user 8.97 s, sys: 0.36 s, total: 9.32 s
# Wall time: 9.25 s
#
# Mean(same): 9.107
# Mean(diff): 9.822
# Difference: 0.716

# %%
# %time result = evaluate.imageToImage(paths, "BRISK", "BRISK", comp)
print
display.scoreHist(result)
# Out:
# =====
# #####
# CPU times: user 17.62 s, sys: 0.76 s, total: 18.38 s
# Wall time: 18.33 s
#
# Mean(same): 3.987
# Mean(diff): 3.753
# Difference: -0.234

# %%
# %load_ext autoreload
# %autoreload 2
